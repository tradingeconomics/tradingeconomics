# %%
import tradingeconomics as te
te.login()
# Out:
# 'You are logged in as a guest:guest'

# %% [markdown]
# # Economic Calendar

# %% [markdown]
# ## Events

# %% [markdown]
# ##### All calendar events
# /calendar
# https://api.tradingeconomics.com/calendar?c=guest:guest

# %%
te.getCalendarData(output_type='df')
# Out:
#   CalendarId                 Date         Country  \
# 0     275586  2021-09-17T00:20:00       Indonesia
# 1     274914  2021-09-17T00:30:00       Singapore
# 2     274915  2021-09-17T00:30:00       Singapore
# 3     274916  2021-09-17T01:00:00       Singapore
# 4     275020  2021-09-17T03:15:00     Philippines
# 5     274929  2021-09-17T06:00:00  United Kingdom
# 6     274930  2021-09-17T06:00:00  United Kingdom
# 7     274931  2021-09-17T06:00:00  United Kingdom
# 8     274932  2021-09-17T06:00:00  United Kingdom
# 9     274935  2021-09-17T07:00:00         Austria
#
#                                     Category                     Event  \
# 0                                   Calendar       Motorbike Sales YoY
# 1  Domestic Exports of Non Oil (nodx) (%yoy)       Non-Oil Exports YoY
# 2     Exports of Non-oil Domestic Exports Of       Non-Oil Exports MoM
# 3                           Balance of Trade          Balance of Trade
# ...

# %% [markdown]
# ##### All calendar events by importance (1-Low, 2-Medium, 3-High)
# /calendar?importance=2
# https://api.tradingeconomics.com/calendar?c=guest:guest&importance=2

# %%
te.getCalendarData(importance='2', output_type='df')
# Out:
#   CalendarId                 Date         Country          Category  \
# 0     280263  2021-09-21T01:30:00       Australia     Interest Rate
# 1     274924  2021-09-21T06:00:00     Switzerland  Balance of Trade
# 2     280837  2021-09-21T07:30:00       Indonesia     Interest Rate
# 3     283052  2021-09-21T07:30:00          Sweden     Interest Rate
# 4     283053  2021-09-21T07:30:00          Sweden     Interest Rate
# 5     275073  2021-09-21T10:00:00  United Kingdom    Factory Orders
# 6     275052  2021-09-21T12:30:00          Canada     Housing Index
# 7     275053  2021-09-21T12:30:00          Canada     Housing Index
# 8     274992  2021-09-21T12:30:00   United States   Current Account
# 9     274993  2021-09-21T12:30:00   United States    Housing Starts
#
#                           Event Reference        ReferenceDate  \
# 0           RBA Meeting Minutes                           None
# 1              Balance of Trade       Aug  2021-08-31T00:00:00
# ...

# %% [markdown]
# ##### Filter calendar events by date or by date and importance
# /calendar/country/All/{yyyy-mm-dd}/{yyyy-mm-dd}
#
# https://api.tradingeconomics.com/calendar/country/All/2016-12-02/2016-12-03?c=guest:guest

# %%
te.getCalendarData(country='all', initDate = '2011-01-01', endDate = '2016-01-01', output_type='df')
# Out:
#   CalendarId                 Date        Country            Category  \
# 0       8857  2012-03-04T00:00:00          Kenya            Calendar
# 1      36803  2012-04-20T00:00:00       Slovakia   Unemployment Rate
# 2      36804  2012-04-20T00:00:00       Slovakia   Unemployment Rate
# 3      36805  2012-04-20T00:00:00       Slovakia   Unemployment Rate
# 4      20240  2012-11-17T22:00:00         Latvia            Calendar
# 5      39094  2012-12-22T14:30:00         Brazil         Loan Growth
# 6      27956  2013-01-02T07:30:00       Thailand       Interest Rate
# 7       4361  2013-01-04T13:30:00  United States   Non Farm Payrolls
# 8       4373  2013-01-04T13:30:00  United States   Unemployment Rate
# 9      22006  2013-01-06T13:00:00        Germany  Inflation Rate Mom
#
#                           Event Reference  \
# 0      Kenyan General Elections
# 1             Unemployment Rate
# 2             Unemployment Rate       Mar
# 3             Unemployment Rate       Mar
# ...

# %% [markdown]
# /calendar/country/All/{yyyy-mm-dd}/{yyyy-mm-dd}?importance=3
#
# https://api.tradingeconomics.com/calendar/country/All/2016-12-02/2016-12-03?c=guest:guest&importance=3

# %%
te.getCalendarData(initDate='2016-01-01', endDate='2016-01-01',importance='3', output_type='df')
# Out:
#   CalendarId                 Date         Country             Category  \
# 0      72216  2016-01-01T01:00:00           China  Business Confidence
# 1      72435  2016-01-04T01:45:00           China    Manufacturing PMI
# 2      72605  2016-01-06T13:30:00          Canada     Balance of Trade
# 3      72604  2016-01-06T13:30:00   United States     Balance of Trade
# 4      72521  2016-01-07T00:30:00       Australia     Balance of Trade
# 5      68174  2016-01-07T10:00:00       Euro Area  Business Confidence
# 6      72606  2016-01-07T15:00:00          Canada  Business Confidence
# 7      72706  2016-01-08T07:00:00         Germany     Balance of Trade
# 8      72746  2016-01-08T09:30:00  United Kingdom     Balance of Trade
# 9      86656  2016-01-08T13:30:00   United States    Non Farm Payrolls
#
#                       Event Reference        ReferenceDate  \
# 0     NBS Manufacturing PMI       Dec  2015-12-31T00:00:00
# 1  Caixin Manufacturing PMI       Dec  2015-12-31T00:00:00
# ...

# %% [markdown]
# ##### Calendar events for specific country or by country and importance
# /calendar/country/{countries}v
# https://api.tradingeconomics.com/calendar/country/united%20states?c=guest:guest

# %%
te.getCalendarData(country='united states',  output_type='df')
# Out:
#   CalendarId                 Date        Country                   Category  \
# 0     262357  2021-09-17T14:00:00  United States        Consumer Confidence
# 1     262358  2021-09-17T14:00:00  United States        Consumer Confidence
# 2     262359  2021-09-17T14:00:00  United States        Consumer Confidence
# 3     262360  2021-09-17T14:00:00  United States        Consumer Confidence
# 4     262361  2021-09-17T14:00:00  United States        Consumer Confidence
# 5     283105  2021-09-17T14:30:00  United States                   Calendar
# 6     262362  2021-09-17T17:00:00  United States             Crude Oil Rigs
# 7     279866  2021-09-17T17:00:00  United States             Crude Oil Rigs
# 8     283084  2021-09-20T00:00:00  United States                   Calendar
# 9     274904  2021-09-20T14:00:00  United States  Nahb Housing Market Index
#
#                                          Event Reference  \
# 0          Michigan Consumer Expectations Prel       Sep
# ...

# %% [markdown]
# /calendar/country/{countries}?importance=3
#
# https://api.tradingeconomics.com/calendar/country/united%20states?c=guest:guest&importance=3

# %%
te.getCalendarData(country='united states',importance='3', output_type='df')
# Out:
#   CalendarId                 Date        Country              Category  \
# 0     258013  2021-09-22T18:00:00  United States         Interest Rate
# 1     258026  2021-09-22T18:00:00  United States         Interest Rate
# 2     258021  2021-09-22T18:30:00  United States         Interest Rate
# 3     275211  2021-09-27T12:30:00  United States  Durable Goods Orders
#
#                         Event Reference        ReferenceDate  \
# 0  Fed Interest Rate Decision            2021-09-22T00:00:00
# 1   FOMC Economic Projections                           None
# 2        Fed Press Conference                           None
# 3    Durable Goods Orders MoM       Aug  2021-08-31T00:00:00
#
#                Source                       SourceURL Actual  ... TEForecast  \
# 0     Federal Reserve  http://www.federalreserve.gov/         ...      0.25%
# 1     Federal Reserve  http://www.federalreserve.gov/         ...
# 2     Federal Reserve  http://www.federalreserve.gov/         ...
# ...

# %% [markdown]
# Calendar events for specific country and date
#
# /calendar/country/{countries}/{yyyy-mm-dd}/{yyyy-mm-dd}
#
# https://api.tradingeconomics.com/calendar/country/united%20states/2016-02-01/2016-02-10?c=guest:guest

# %%
te.getCalendarData(country = 'United States', initDate = '2011-01-01', endDate = '2016-01-01', output_type='df')
# Out:
#   CalendarId                 Date        Country             Category  \
# 0       4361  2013-01-04T13:30:00  United States    Non Farm Payrolls
# 1       4373  2013-01-04T13:30:00  United States    Unemployment Rate
# 2     179642  2013-01-23T09:30:00  United States  Total Vehicle Sales
# 3     181138  2013-01-23T09:30:00  United States  Total Vehicle Sales
# 4     227125  2013-01-23T09:30:00  United States        Interest Rate
# 5     229420  2013-01-23T09:30:00  United States        Interest Rate
# 6     229176  2013-01-23T09:30:00  United States        Interest Rate
# 7     228832  2013-01-23T09:30:00  United States        Interest Rate
# 8     227986  2013-01-23T09:30:00  United States        Interest Rate
# 9     228129  2013-01-23T09:30:00  United States             Calendar
#
#                                         Event Reference  \
# 0                           Non Farm Payrolls  DEC 2012
# 1                           Unemployment Rate  DEC 2012
# ...

# %% [markdown]
# Calendar events for specific country and date and importance
# /calendar/country/{countries}/{yyyy-mm-dd}/{yyyy-mm-dd}?importance=3
#
# https://api.tradingeconomics.com/calendar/country/united%20states/2016-02-01/2016-02-10?c=guest:guest&importance=3

# %%
te.getCalendarData(country='united states',initDate='2016-01-01', endDate='2016-01-01',importance='3', output_type='df')
# Out:
#   CalendarId                 Date        Country              Category  \
# 0      72604  2016-01-06T13:30:00  United States      Balance of Trade
# 1      86656  2016-01-08T13:30:00  United States     Non Farm Payrolls
# 2      72889  2016-01-15T13:30:00  United States      Retail Sales MoM
# 3      72980  2016-01-20T13:30:00  United States        Inflation Rate
# 4      72983  2016-01-20T13:30:00  United States   Core Inflation Rate
# 5      73226  2016-01-28T13:30:00  United States  Durable Goods Orders
# 6      73494  2016-02-01T13:30:00  United States       Personal Income
# 7      73495  2016-02-01T13:30:00  United States     Personal Spending
# 8      86710  2016-02-05T13:30:00  United States     Non Farm Payrolls
# 9      73660  2016-02-05T13:30:00  United States      Balance of Trade
#
#                       Event Reference        ReferenceDate  \
# 0          Balance of Trade       Nov  2015-11-30T00:00:00
# 1         Non Farm Payrolls       Dec  2015-12-31T00:00:00
# ...

# %% [markdown]
# ##### Calendar events for a specific indicator or by indicator and importance
# /calendar/indicator/{indicators}
#
# https://api.tradingeconomics.com/calendar/indicator/inflation%20rate?c=guest:guest

# %%
te.getCalendarData(category='inflation rate', output_type='df')
# Out:
#   CalendarId                 Date       Country        Category  \
# 0     275017  2021-09-21T10:00:00         Macau  Inflation Rate
# 1     275051  2021-09-21T12:00:00        Malawi  Inflation Rate
# 2     271197  2021-09-22T08:00:00        Kuwait  Inflation Rate
# 3     275450  2021-09-22T08:00:00  South Africa  Inflation Rate
# 4     275018  2021-09-22T10:00:00    Bangladesh  Inflation Rate
# 5     275072  2021-09-22T12:30:00       Morocco  Inflation Rate
# 6     275106  2021-09-23T02:00:00    East Timor  Inflation Rate
# 7     275099  2021-09-23T05:00:00     Singapore  Inflation Rate
# 8     275062  2021-09-23T10:00:00       Lebanon  Inflation Rate
# 9     275131  2021-09-23T11:00:00   Ivory Coast  Inflation Rate
#
#                 Event Reference        ReferenceDate  \
# 0  Inflation Rate YoY       Aug  2021-08-31T00:00:00
# 1  Inflation Rate YoY       Aug  2021-08-31T00:00:00
# 2  Inflation Rate YoY       May  2021-05-31T00:00:00
# ...

# %% [markdown]
# ##### Calendar events for a specific indicator and importance
#
# /calendar/indicator/{indicators}?importance=2
#
# https://api.tradingeconomics.com/calendar/indicator/inflation%20rate?c=guest:guest&importance=2

# %%
te.getCalendarData(category='inflation rate',importance='2', output_type='df')
# Out:
#   CalendarId                 Date       Country        Category  \
# 0     275450  2021-09-22T08:00:00  South Africa  Inflation Rate
# 1     275095  2021-09-24T04:00:00      Malaysia  Inflation Rate
#
#                 Event Reference        ReferenceDate  \
# 0  Inflation Rate YoY       Aug  2021-08-31T00:00:00
# 1  Inflation Rate YoY       Aug  2021-08-31T00:00:00
#
#                                Source                   SourceURL Actual  ...  \
# 0             Statistics South Africa  http://www.statssa.gov.za/         ...
# 1  Department of Statistics, Malaysia     https://www.dosm.gov.my         ...
#
#   TEForecast                          URL DateSpan Importance  \
# 0       4.8%  /south-africa/inflation-cpi        0          2
# 1       2.2%      /malaysia/inflation-cpi        0          2
#
#             LastUpdate  Revised Currency Unit    Ticker    Symbol
# 0  2021-09-20T16:00:00                      %  SACPIYOY  SACPIYOY
# ...

# %% [markdown]
# ##### Calendar events for a specific indicator and by date
# /calendar/indicator/{indicators}/{yyyy-mm-dd}/{yyyy-mm-dd}
#
# https://api.tradingeconomics.com/calendar/indicator/inflation%20rate/2016-03-01/2016-03-03?c=guest:guest

# %%
te.getCalendarData(category='inflation rate',initDate='2016-03-01', endDate='2016-03-03', output_type='df')
# Out:
#   CalendarId                 Date      Country        Category  \
# 0      72249  2016-03-01T04:00:00    Indonesia  Inflation Rate
# 1      74526  2016-03-01T04:00:00     Thailand  Inflation Rate
# 2      89887  2016-03-01T05:00:00         Peru  Inflation Rate
# 3      74548  2016-03-01T08:05:00     Pakistan  Inflation Rate
# 4      74684  2016-03-02T10:55:00   Luxembourg  Inflation Rate
# 5      74635  2016-03-02T18:00:00     Paraguay  Inflation Rate
# 6      74591  2016-03-02T23:00:00  South Korea  Inflation Rate
# 7      74608  2016-03-03T08:00:00       Turkey  Inflation Rate
# 8      74733  2016-03-03T10:00:00       Cyprus  Inflation Rate
# 9      74701  2016-03-03T17:20:00      Uruguay  Inflation Rate
#
#                 Event Reference        ReferenceDate  \
# 0  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# 1  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# 2  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# 3  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# ...

# %% [markdown]
# ##### Calendar events for a specific indicator and by date and by importance
# /calendar/indicator/{indicators}/{yyyy-mm-dd}/{yyyy-mm-dd}?importance=2
#
# https://api.tradingeconomics.com/calendar/indicator/inflation%20rate/2016-03-01/2016-03-03?c=guest:guest&importance=2

# %%
te.getCalendarData(category='inflation rate',initDate='2016-03-01', endDate='2016-03-03',importance='2', output_type='df')
# Out:
#   CalendarId                 Date      Country        Category  \
# 0      72249  2016-03-01T04:00:00    Indonesia  Inflation Rate
# 1      74591  2016-03-02T23:00:00  South Korea  Inflation Rate
# 2      74608  2016-03-03T08:00:00       Turkey  Inflation Rate
# 3      74711  2016-03-04T01:00:00  Philippines  Inflation Rate
# 4      74740  2016-03-04T13:00:00       Russia  Inflation Rate
# 5      74782  2016-03-08T08:15:00  Switzerland  Inflation Rate
# 6      74803  2016-03-09T12:00:00       Brazil  Inflation Rate
# 7      74865  2016-03-09T14:00:00       Mexico  Inflation Rate
# 8      74724  2016-03-10T05:30:00  Netherlands  Inflation Rate
# 9      75012  2016-03-10T11:00:00      Ireland  Inflation Rate
#
#                 Event Reference        ReferenceDate  \
# 0  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# 1  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# 2  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# 3  Inflation Rate YoY       Feb  2016-02-29T00:00:00
# ...

# %% [markdown]
# ##### All calendar events for multiple countries or by countries and importance
# /calendar/country/{countries}
# https://api.tradingeconomics.com/calendar/country/united%20states,china?c=guest:guest

# %%
te.getCalendarData(country = ['United States','china'], output_type='df')
# Out:
#   CalendarId                 Date        Country                   Category  \
# 0     262357  2021-09-17T14:00:00  United States        Consumer Confidence
# 1     262358  2021-09-17T14:00:00  United States        Consumer Confidence
# 2     262359  2021-09-17T14:00:00  United States        Consumer Confidence
# 3     262360  2021-09-17T14:00:00  United States        Consumer Confidence
# 4     262361  2021-09-17T14:00:00  United States        Consumer Confidence
# 5     283105  2021-09-17T14:30:00  United States                   Calendar
# 6     262362  2021-09-17T17:00:00  United States             Crude Oil Rigs
# 7     279866  2021-09-17T17:00:00  United States             Crude Oil Rigs
# 8     283084  2021-09-20T00:00:00  United States                   Calendar
# 9     274904  2021-09-20T14:00:00  United States  Nahb Housing Market Index
#
#                                          Event Reference  \
# 0          Michigan Consumer Expectations Prel       Sep
# ...

# %% [markdown]
# /calendar/country/{countries}?importance=2
# https://api.tradingeconomics.com/calendar/country/united%20states,china?c=guest:guest&importance=2

# %%
te.getCalendarData(country=['united states','china'], importance='2', output_type='df')
# Out:
#   CalendarId                 Date        Country                    Category  \
# 0     274992  2021-09-21T12:30:00  United States             Current Account
# 1     274993  2021-09-21T12:30:00  United States              Housing Starts
# 2     274994  2021-09-21T12:30:00  United States            Building Permits
# 3     274995  2021-09-21T12:30:00  United States              Housing Starts
# 4     274996  2021-09-21T12:30:00  United States            Building Permits
# 5     262372  2021-09-21T20:30:00  United States  API Crude Oil Stock Change
# 6     280235  2021-09-22T01:30:00          China                    Calendar
# 7     275079  2021-09-22T14:00:00  United States         Existing Home Sales
# 8     275080  2021-09-22T14:00:00  United States         Existing Home Sales
# 9     262380  2021-09-22T14:30:00  United States      Gasoline Stocks Change
#
#                         Event Reference        ReferenceDate  \
# ...

# %% [markdown]
# ##### All calendar events for multiple countries and by date
# /calendar/country/{countries}/{yyyy-mm-dd}/{yyyy-mm-dd}
# https://api.tradingeconomics.com/calendar/country/united%20states,china/2016-02-10/2016-02-11?c=guest:guest

# %%
te.getCalendarData(country=['united states', 'china'], initDate = '2016-01-01', endDate = '2016-01-03', output_type='df')
# Out:
#   CalendarId                 Date        Country             Category  \
# 0       4361  2013-01-04T13:30:00  United States    Non Farm Payrolls
# 1       4373  2013-01-04T13:30:00  United States    Unemployment Rate
# 2     229176  2013-01-23T09:30:00  United States        Interest Rate
# 3     227125  2013-01-23T09:30:00  United States        Interest Rate
# 4     227897  2013-01-23T09:30:00  United States        Interest Rate
# 5     229420  2013-01-23T09:30:00  United States        Interest Rate
# 6     228832  2013-01-23T09:30:00  United States        Interest Rate
# 7     181138  2013-01-23T09:30:00  United States  Total Vehicle Sales
# 8     227863  2013-01-23T09:30:00  United States             Calendar
# 9     227864  2013-01-23T09:30:00  United States             Calendar
#
#                                     Event Reference  \
# 0                       Non Farm Payrolls  DEC 2012
# 1                       Unemployment Rate  DEC 2012
# ...

# %% [markdown]
# ##### All calendar events for multiple countries and importance and by date
# /calendar/country/{countries}/{yyyy-mm-dd}/{yyyy-mm-dd}?importance=2
# https://api.tradingeconomics.com/calendar/country/united%20states,china/2016-02-10/2016-02-11?c=guest:guest&importance=2

# %%
te.getCalendarData(country=['united states', 'china'], initDate = '2016-01-01', endDate = '2016-01-03',importance=2, output_type='df')
# Out:
#   CalendarId                 Date        Country               Category  \
# 0      72479  2016-01-01T01:00:00          China  Non Manufacturing PMI
# 1      89542  2016-01-03T18:15:00  United States          Interest Rate
# 2      72472  2016-01-04T14:45:00  United States      Manufacturing PMI
# 3      88334  2016-01-04T15:00:00  United States    Business Confidence
# 4      72473  2016-01-04T15:00:00  United States    Business Confidence
# 5      72476  2016-01-04T15:00:00  United States    Business Confidence
# 6      72477  2016-01-04T15:00:00  United States    Business Confidence
# 7      72310  2016-01-04T15:00:00  United States  Construction Spending
# 8      72517  2016-01-05T20:45:00  United States    Total Vehicle Sales
# 9      72530  2016-01-06T01:45:00          China           Services PMI
#
#                             Event Reference        ReferenceDate  \
# 0           Non Manufacturing PMI       Dec  2015-12-31T00:00:00
# ...

# %% [markdown]
# ##### Calendar events for a specific country and specific indicator
# /calendar/country/{countries}/indicator/{indicators}
# https://api.tradingeconomics.com/calendar/country/united%20states/indicator/initial%20jobless%20claims?c=guest:guest

# %%
te.getCalendarData(country = 'United States', category = 'initial jobless claims', output_type='df')
# Out:
#   CalendarId                 Date        Country                Category  \
# 0       4318  2013-03-07T13:30:00  United States  Initial Jobless Claims
# 1       4319  2013-03-14T12:30:00  United States  Initial Jobless Claims
# 2       4320  2013-03-21T12:30:00  United States  Initial Jobless Claims
# 3       4321  2013-03-28T12:30:00  United States  Initial Jobless Claims
# 4       4322  2013-04-04T13:30:00  United States  Initial Jobless Claims
# 5       4323  2013-04-11T13:30:00  United States  Initial Jobless Claims
# 6       4324  2013-04-18T13:30:00  United States  Initial Jobless Claims
# 7       4325  2013-04-25T13:30:00  United States  Initial Jobless Claims
# 8       4326  2013-05-02T13:30:00  United States  Initial Jobless Claims
# 9       4327  2013-05-09T13:30:00  United States  Initial Jobless Claims
#
#                     Event      Reference                    Source Actual  \
# 0  Initial Jobless Claims  25/FEB-02/MAR  U.S. Department of Labor   340K
# ...

# %% [markdown]
# ##### Calendar events for a specific country and specific indicator and date
# /calendar/country/{countries}/indicator/{indicators}/{yyyy-mm-dd}/{yyyy-mm-dd}
# https://api.tradingeconomics.com/calendar/country/united%20states/indicator/initial%20jobless%20claims/2016-12-01/2017-02-25?c=guest:guest

# %%
te.getCalendarData(country = 'United States', category = 'initial jobless claims',initDate = '2011-01-01', endDate = '2016-01-01', output_type='df')
# Out:
#   CalendarId                 Date        Country                Category  \
# 0       4318  2013-03-07T13:30:00  United States  Initial Jobless Claims
# 1       4319  2013-03-14T12:30:00  United States  Initial Jobless Claims
# 2       4320  2013-03-21T12:30:00  United States  Initial Jobless Claims
# 3       4321  2013-03-28T12:30:00  United States  Initial Jobless Claims
# 4       4322  2013-04-04T13:30:00  United States  Initial Jobless Claims
# 5       4323  2013-04-11T13:30:00  United States  Initial Jobless Claims
# 6       4324  2013-04-18T13:30:00  United States  Initial Jobless Claims
# 7       4325  2013-04-25T13:30:00  United States  Initial Jobless Claims
# 8       4326  2013-05-02T13:30:00  United States  Initial Jobless Claims
# 9       4327  2013-05-09T13:30:00  United States  Initial Jobless Claims
#
#                     Event      Reference                    Source Actual  \
# 0  Initial Jobless Claims  25/FEB-02/MAR  U.S. Department of Labor   340K
# ...

# %% [markdown]
# ##### Filter calendar events by calendar ID
# /calendar/calendarid/{calendarids}?c=guest:guest
# https://api.tradingeconomics.com/calendar/calendarid/174108,160025,160030?c=guest:guest

# %%
te.getCalendarId(id=['160025','160030', '174108'], output_type='df')
# Out:
#   CalendarId                 Date     Country        Category  \
# 0     160025  2018-06-21T07:00:00       Spain  Factory Orders
# 1     160030  2018-06-23T06:15:00     Bahrain  Inflation Rate
# 2     174108  2018-06-19T00:00:00  Azerbaijan        Holidays
#
#                              Event Reference Unit  \
# 0            Industrial Orders YoY       Apr    %
# 1               Inflation Rate YoY       May    %
# 2  End of Ramadan (Substitute Day)
#
#                                               Source Actual Previous Forecast  \
# 0                National Statistics Institute (INE)   4.8%     3.9%
# 1  Central Informatics Organisation - Kingdom of ...   2.8%     2.6%
# 2
#
#   TEForecast  Importance
# 0       4.5%           1
# 1      2.80%           1
# 2                      1

# %% [markdown]
# ##### Filter calendar events by ticker and date
# /calendar/ticker/{ticker}?c=guest:guest
# https://api.tradingeconomics.com/calendar/ticker/IJCUSA,SPAINFACORD,BAHRAININFNRATE?c=guest:guest

# %%
te.getCalendarData(ticker=['IJCUSA','SPAINFACORD','BAHRAININFNRATE'], output_type='df')
# Out:
#   CalendarId                 Date        Country                Category  \
# 0     262352  2021-09-16T12:30:00  United States  Initial Jobless Claims
# 1     262321  2021-09-09T12:30:00  United States  Initial Jobless Claims
# 2     262284  2021-09-02T12:30:00  United States  Initial Jobless Claims
# 3     274144  2021-09-02T01:30:00        Bahrain          Inflation Rate
# 4     262248  2021-08-26T12:30:00  United States  Initial Jobless Claims
# 5     262219  2021-08-19T12:30:00  United States  Initial Jobless Claims
# 6     262183  2021-08-12T12:30:00  United States  Initial Jobless Claims
# 7     272396  2021-08-09T02:15:00        Bahrain          Inflation Rate
# 8     262146  2021-08-05T12:30:00  United States  Initial Jobless Claims
# 9     262110  2021-07-29T12:30:00  United States  Initial Jobless Claims
#
#                     Event Reference        ReferenceDate  \
# 0  Initial Jobless Claims    11/Sep  2021-09-11T00:00:00
# ...

# %% [markdown]
# ##### Filter calendar events by ticker and date
# /calendar/ticker/{ticker}/{yyyy-mm-dd}/{yyyy-mm-dd}?c=guest:guest
# https://api.tradingeconomics.com/calendar/ticker/IJCUSA,SPAINFACORD,BAHRAININFNRATE/2018-01-01/2018-03-01?c=guest:guest

# %%
te.getCalendarData(ticker=['IJCUSA','SPAINFACORD','BAHRAININFNRATE'], initDate = '2021-01-01', endDate = '2021-01-03',output_type='df')
# Out:
#   CalendarId                 Date        Country                Category  \
# 0     261604  2021-04-15T12:30:00  United States  Initial Jobless Claims
# 1     261573  2021-04-08T12:30:00  United States  Initial Jobless Claims
# 2     261536  2021-04-01T12:30:00  United States  Initial Jobless Claims
# 3     266811  2021-03-31T09:30:00        Bahrain          Inflation Rate
# 4     261500  2021-03-25T12:30:00  United States  Initial Jobless Claims
# 5     261471  2021-03-18T12:30:00  United States  Initial Jobless Claims
# 6     261435  2021-03-11T13:30:00  United States  Initial Jobless Claims
# 7     261398  2021-03-04T13:30:00  United States  Initial Jobless Claims
# 8     265433  2021-02-28T08:30:00        Bahrain          Inflation Rate
# 9     261362  2021-02-25T13:30:00  United States  Initial Jobless Claims
#
#                     Event Reference        ReferenceDate  \
# 0  Initial Jobless Claims    10/Apr  2021-04-10T00:00:00
# ...
