# %%
import tradingeconomics as te

# %%
te.login()
# Out:
# 'You are logged in as a guest:guest'

# %% [markdown]
# # Eurostat

# %% [markdown]
# ## Categories and Countries

# %% [markdown]
# ##### List of countries available.
# /eurostat/countries

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/countries?c=guest:guest

# %%
te.getEurostatCountries(output_type='df')
# Out:
#            Country
# 0          Austria
# 1          Belgium
# 2         Bulgaria
# 3          Croatia
# 4           Cyprus
# 5   Czech Republic
# 6          Denmark
# 7          Estonia
# 8        Euro Area
# 9   European Union
# 10         Finland
# 11          France
# 12         Germany
# 13          Greece
# 14         Hungary
# 15         Ireland
# 16           Italy
# 17          Latvia
# 18       Lithuania
# 19      Luxembourg
# 20           Malta
# 21     Netherlands
# 22          Poland
# 23        Portugal
# 24         Romania
# 25        Slovakia
# 26        Slovenia
# 27           Spain
# 28          Sweden

# %% [markdown]
# ##### List of categories and category groups available.
# /eurostat/categories

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/categories?c=guest:guest

# %%
te.getEurostatCategoryGroups(output_type='df')
# Out:
#                                             Category CategoryGroup
# 0  Wheat and spelt: Area (cultivation/harvested/p...   Agriculture
# 1  Rye and winter cereal mixtures: Area (cultivat...   Agriculture
# 2    Barley: Area (cultivation/harvested/production)   Agriculture
# 3  Oats and spring cereal mixtures: Area (cultiva...   Agriculture
# 4  Cereals for the production of grain (including...   Agriculture
# 5  Grain maize and corn-cob-mix: Area (cultivatio...   Agriculture
# 6  Dry pulses and protein crops for the productio...   Agriculture
# 7  Area under cultivation of Rape and turnip rape...   Agriculture
# 8           Area under cultivation of Sunflower seed   Agriculture
# 9                     Area under cultivation of Soya   Agriculture

# %% [markdown]
# ##### Get Eurostat data by Category Group.
# /eurostat?category_goup={category_group}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat?category_group=Poverty&c=guest:guest

# %%
te.getEurostatData(category_group='poverty', output_type='df')
# Out:
#       ID         Country                                           Category  \
# 0  15371        Bulgaria  People at risk of income poverty after social ...
# 1  15373  Czech Republic  People at risk of income poverty after social ...
# 2  15375         Denmark  People at risk of income poverty after social ...
# 3  15383          Greece  People at risk of income poverty after social ...
# 4  15395          Latvia  People at risk of income poverty after social ...
# 5  15401         Hungary  People at risk of income poverty after social ...
# 6  15403           Malta  People at risk of income poverty after social ...
# 7  15407         Austria  People at risk of income poverty after social ...
# 8  15409          Poland  People at risk of income poverty after social ...
# 9  15413         Romania  People at risk of income poverty after social ...
#
#   CategoryGroup                                                URL Unit  \
# ...

# %% [markdown]
# ##### Get Eurostat data by Category.
# /eurostat?category={category}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat?category=People%20at%20risk%20of%20income%20poverty%20after%20social%20transfers&c=guest:guest

# %%
te.getEurostatData(category='People at risk of income poverty after social transfers', output_type='df')
# Out:
#       ID         Country                                           Category  \
# 0  15371        Bulgaria  People at risk of income poverty after social ...
# 1  15373  Czech Republic  People at risk of income poverty after social ...
# 2  15375         Denmark  People at risk of income poverty after social ...
# 3  15383          Greece  People at risk of income poverty after social ...
# 4  15395          Latvia  People at risk of income poverty after social ...
# 5  15401         Hungary  People at risk of income poverty after social ...
# 6  15403           Malta  People at risk of income poverty after social ...
# 7  15407         Austria  People at risk of income poverty after social ...
# 8  15409          Poland  People at risk of income poverty after social ...
# 9  15413         Romania  People at risk of income poverty after social ...
#
#   CategoryGroup                                                URL Unit  \
# ...

# %% [markdown]
# ##### Get Eurostat data by Country.
# /eurostat/country/{country}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/country/Denmark?c=guest:guest

# %%
te.getEurostatData(country='denmark', output_type='df')
# Out:
#      ID  Country                                           Category  \
# 0   622  Denmark  Wheat and spelt: Area (cultivation/harvested/p...
# 1   751  Denmark  Rye and winter cereal mixtures: Area (cultivat...
# 2   880  Denmark    Barley: Area (cultivation/harvested/production)
# 3  1009  Denmark  Oats and spring cereal mixtures: Area (cultiva...
# 4  1138  Denmark  Cereals for the production of grain (including...
# 5  1267  Denmark  Grain maize and corn-cob-mix: Area (cultivatio...
# 6  1396  Denmark  Dry pulses and protein crops for the productio...
# 7  1525  Denmark  Area under cultivation of Rape and turnip rape...
# 8  1654  Denmark  Green maize: Area (cultivation/harvested/produ...
# 9  2012  Denmark  Area under cultivation of Fresh vegetables (in...
#
#   CategoryGroup                                                URL  \
# 0   Agriculture  /denmark/wheat-spelt-area-cultivation-harveste...
# 1   Agriculture  /denmark/rye-winter-cereal-mixtures-area-culti...
# ...

# %% [markdown]
# ##### Get Eurostat data by Country and category.
# /eurostat/country/{country}?category={category}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/country/European%20Union?category=Harmonised%20unemployment%20rate:%20Females&c=guest:guest

# %%
te.getEurostatData(country='european union', category='Harmonised unemployment rate: Females', output_type='df')
# Out:
#      ID         Country                               Category CategoryGroup  \
# 0  7173  European Union  Harmonised unemployment rate: Females        Labour
#
#                                                  URL Unit Frequency  \
# 0  /european-union/harmonised-unemployment-rate-f...    %   Monthly
#
#    LatestValue      LatestValueDate  PreviousValue    PreviousValueDate  \
# 0          7.3  2021-07-31T00:00:00            7.5  2021-06-30T00:00:00
#
#    FirstValue       FirstValueDate  HighestValue     HighestValueDate  \
# 0         8.1  2020-09-30T00:00:00           8.1  2020-09-30T00:00:00
#
#    LowestValue      LowestValueDate           LastUpdate
# 0          7.3  2021-07-31T00:00:00  2021-09-16T23:23:00

# %% [markdown]
# ##### Get Eurostat data by Country and category group.
# /eurostat/country/{country}?category_group={category_group}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/country/Denmark?category_group=Interest%20rates&c=guest:guest

# %%
te.getEurostatData(country='european union', category_group='interest rates', output_type='df')
# Out:
#       ID         Country                          Category   CategoryGroup  \
# 0   7524  European Union        Long term gov. bond yields  Interest rates
# 1  12611  European Union  EMU convergence criterion series  Interest rates
#
#                                                  URL Unit Frequency  \
# 0  /european-union/long-term-gov-bond-yields-euro...    %   Monthly
# 1  /european-union/emu-convergence-criterion-seri...    %    Yearly
#
#    LatestValue      LatestValueDate  PreviousValue    PreviousValueDate  \
# 0         0.23  2021-08-31T00:00:00           0.31  2021-07-31T00:00:00
# 1         0.31  2020-12-31T00:00:00           0.72  2019-12-31T00:00:00
#
#    FirstValue       FirstValueDate  HighestValue     HighestValueDate  \
# 0        0.22  2020-09-30T00:00:00          0.50  2021-05-31T00:00:00
# 1        4.23  2009-12-31T00:00:00          4.49  2011-12-31T00:00:00
#
#    LowestValue      LowestValueDate           LastUpdate
# ...

# %% [markdown]
# ##### Get historical data by ID.
# /eurostat/historical/{id}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/historical/24804?c=guest:guest

# %%
te.getHistoricalEurostat(ID='24804', output_type='df')
# Out:
#       ID                 Date  Value           LastUpdate
# 0  24804  2020-12-31T00:00:00    2.4  2021-04-20T23:16:00
# 1  24804  2019-12-31T00:00:00    1.8  2020-07-02T17:46:00
# 2  24804  2018-12-31T00:00:00    2.1  2020-07-02T17:46:00
# 3  24804  2017-12-31T00:00:00    2.7  2020-07-02T17:46:00
# 4  24804  2016-12-31T00:00:00    3.5  2020-07-02T17:46:00
# 5  24804  2015-12-31T00:00:00    4.7  2020-07-02T17:46:00
# 6  24804  2014-12-31T00:00:00    6.0  2020-07-02T17:46:00
# 7  24804  2013-12-31T00:00:00    6.8  2020-07-02T17:46:00
# 8  24804  2012-12-31T00:00:00    6.5  2020-07-02T17:46:00
# 9  24804  2011-12-31T00:00:00    6.4  2020-07-02T17:46:00

# %% [markdown]
# ##### Get historical data by ID and a start date.
# /eurostat/historical/{id}?d1={yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/historical/24804?d1=2015-01-01&c=guest:guest

# %%
te.getHistoricalEurostat(ID='24804', initDate='2015-01-01', output_type='df')
# Out:
#       ID                 Date  Value           LastUpdate
# 0  24804  2020-12-31T00:00:00    2.4  2021-04-20T23:16:00
# 1  24804  2019-12-31T00:00:00    1.8  2020-07-02T17:46:00
# 2  24804  2018-12-31T00:00:00    2.1  2020-07-02T17:46:00
# 3  24804  2017-12-31T00:00:00    2.7  2020-07-02T17:46:00
# 4  24804  2016-12-31T00:00:00    3.5  2020-07-02T17:46:00
# 5  24804  2015-12-31T00:00:00    4.7  2020-07-02T17:46:00

# %% [markdown]
# ##### Get historical data by ID and a date range.
# /eurostat/historical/{id}?d1={yyyy-mm-dd}&d2={yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/eurostat/historical/24804?d1=2016-01-01&d2=2020-01-01&c=guest:guest

# %%
te.getHistoricalEurostat(ID='24804', initDate='2016-01-01', endDate='2020-01-01', output_type='df')
# Out:
#       ID                 Date  Value           LastUpdate
# 0  24804  2019-12-31T00:00:00    1.8  2020-07-02T17:46:00
# 1  24804  2018-12-31T00:00:00    2.1  2020-07-02T17:46:00
# 2  24804  2017-12-31T00:00:00    2.7  2020-07-02T17:46:00
# 3  24804  2016-12-31T00:00:00    3.5  2020-07-02T17:46:00
