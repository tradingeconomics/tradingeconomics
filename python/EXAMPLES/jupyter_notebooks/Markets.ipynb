# %%
import tradingeconomics as te
te.login()
# Out:
# 'You are logged in as a guest:guest'

# %% [markdown]
# # Markets

# %% [markdown]
# ## Markets List

# %% [markdown]
# ##### 1  Commodities
# /markets/commodities
# https://api.tradingeconomics.com/markets/commodities?c=guest:guest

# %%
te.getMarketsData(marketsField='commodities', output_type='df')
# Out:
#          Symbol    Ticker        Name    Country                 Date  \
# 0      BDIY:IND    BALTIC  Baltic Dry  commodity  2021-09-16T00:00:00
# 1      BEEF:COM      Beef        Beef  commodity  2021-09-16T00:00:00
# 2       CHE:COM   CHEESE1      Cheese  commodity  2021-09-16T00:00:00
# 3     CRYTR:IND       CRB   CRB Index  commodity  2021-09-16T00:00:00
# 4       DL1:COM       DL1     Ethanol  commodity  2021-09-16T00:00:00
# 5       GAC:COM       GAC     Gallium  Commodity  2021-09-16T00:00:00
# 6  GECNYBGQ:COM  GECNYBGQ   Germanium  Commodity  2021-09-16T00:00:00
# 7       IMR:COM       IMR   Manganese  commodity  2021-09-16T00:00:00
# 8       IUC:COM       IUC      Indium  Commodity  2021-09-16T00:00:00
# 9      LCO1:COM    Cobalt      Cobalt  commodity  2021-09-16T00:00:00
#
#         Last      Close            CloseDate         Group  \
# 0   4215.000   4215.000  2021-09-16T00:00:00         Index
# 1     20.410     20.410  2021-09-16T00:00:00     Livestock
# ...

# %% [markdown]
# ##### 2 Major Currencies
# /markets/currency
# https://api.tradingeconomics.com/markets/currency?c=guest:guest

# %%
te.getMarketsData(marketsField='currency', output_type='df')
# Out:
#        Symbol  Ticker    Name               Country                 Date  \
# 0  AUDUSD:CUR     AUD  AUDUSD             australia  2021-09-17T14:42:00
# 1  BTCUSD:CUR  BTCUSD  BTCUSD                 Other  2021-09-17T14:42:00
# 2     DXY:CUR     USD     DXY         United States  2021-09-17T14:43:00
# 3  EURUSD:CUR     EUR  EURUSD             euro area  2021-09-17T14:43:00
# 4  GBPUSD:CUR     GBP  GBPUSD        united kingdom  2021-09-17T14:42:00
# 5  NZDUSD:CUR     NZD  NZDUSD           new zealand  2021-09-17T14:43:00
# 6  USDAED:CUR     AED  USDAED  united arab emirates  2021-09-17T14:40:00
# 7  USDAFN:CUR  USDAFN  USDAFN           afghanistan  2021-09-17T14:36:00
# 8  USDALL:CUR  USDALL  USDALL               albania  2021-09-17T14:39:00
# 9  USDAMD:CUR  USDAMD  USDAMD               armenia  2021-09-17T14:26:00
#
#           Last        Close            CloseDate  \
# 0      0.72759      0.72759  2021-09-17T14:42:00
# 1  47402.87000  47402.87000  2021-09-17T14:42:00
# ...

# %% [markdown]
# ##### 3 Currency Crosses
# /markets/currency?cross=eur
# https://api.tradingeconomics.com/markets/currency?c=guest:guest&cross=EUR

# %%
te.getCurrencyCross(cross='eur', output_type='df')
# Out:
#        Symbol  Ticker    Name Country                 Date        Last  \
# 0  EURAED:CUR  EURAED  EURAED   Other  2021-09-17T00:00:00    4.325530
# 1  EURAFN:CUR  EURAFN  EURAFN   Other  2021-09-16T00:00:00   99.973570
# 2  EURALL:CUR  EURALL  EURALL   Other  2021-09-17T00:00:00  120.951844
# 3  EURAMD:CUR  EURAMD  EURAMD   Other  2021-09-17T00:00:00  576.847256
# 4  EURAOA:CUR  EURAOA  EURAOA   Other  2021-09-17T00:00:00  724.629724
# 5  EURARS:CUR  EURARS  EURARS   Other  2021-09-13T00:00:00  115.950580
# 6  EURAUD:CUR  EURAUD  EURAUD   Other  2021-09-17T14:43:00    1.614180
# 7  EURAZN:CUR  EURAZN  EURAZN   Other  2021-09-17T00:00:00    1.993880
# 8  EURBDT:CUR  EURBDT  EURBDT   Other  2021-09-16T00:00:00  100.276140
# 9  EURBGN:CUR  EURBGN  EURBGN   Other  2021-09-17T00:00:00    1.955369
#
#         Close            CloseDate                Group          URL  ...  \
# 0    4.325530  2021-09-17T00:00:00                       /euraed:cur  ...
# ...

# %% [markdown]
# ##### 4 Stock Market Indexes
# /markets/index
# https://api.tradingeconomics.com/markets/index?c=guest:guest

# %%
te.getMarketsData(marketsField='index', output_type='df')
# Out:
#         Symbol           Ticker                       Name     Country  \
# 0   TA-100:IND            TA-25                     TA-125      Israel
# 1   TA-125:IND            TA-25                     TA-125      Israel
# 2   TEDPIX:IND           TEDPIX                     TEDPIX        Iran
# 3   BGSMDC:IND   BOTSWANASTOMAR                   Gaborone    Botswana
# 4      BSX:IND              BSX                        BSX     Bermuda
# 5     BVQA:IND  ECUADORSTOARKET      Ecuador General Index     Ecuador
# 6  CRSMBCT:IND          CRSMBCT                   BCT Corp  Costa Rica
# 7      DSM:IND      QATARSTOMAR                         QE       Qatar
# 8    INDZI:IND            INDZI  Zimbabwe Industrial Index    Zimbabwe
# 9  KNSMIDX:IND      KENYASTOMAR                 Nairobi 20       Kenya
#
#                   Date        Last       Close            CloseDate    Group  \
# 0  2021-01-05T15:14:00     1558.08     1558.08  2021-01-05T00:00:00     Asia
# ...

# %% [markdown]
# ##### 5 Government Bonds
# /markets/bond
# https://api.tradingeconomics.com/markets/bond?c=guest:guest

# %%
te.getMarketsData(marketsField='bond', output_type='df')
# Out:
#              Symbol              Ticker           Name    Country  \
# 0      GISR10YR:GOV            GISR10YR     Israel 10Y     israel
# 1      GMXN10YR:IND            GMXN10YR     Mexico 10Y     mexico
# 2    BGRGOVB10Y:GOV   BULGARIAGOVBON10Y   Bulgaria 10Y   bulgaria
# 3  CHLGOVBON10Y:GOV      CHILEGOVBON10Y      Chile 10Y      chile
# 4  LTUGOVBON10Y:GOV  LITHUANIAGOVBON10Y  Lithuania 10Y  Lithuania
# 5  LVAGOVBON10Y:GOV     LATVIAGOVBON10Y     Latvia 10Y     latvia
# 6  NGAGOVBON10Y:GOV    NIGERIAGOVBON10Y    Nigeria 10Y    nigeria
# 7        RUGE1M:GOV              RUGE1M      Russia 1M     Russia
# 8        RUGE3M:GOV              RUGE3M      Russia 3M     Russia
# 9        RUGE6M:GOV              RUGE6M      Russia 6M     Russia
#
#                   Date    Last   Close            CloseDate  \
# 0  2021-09-14T13:27:00   1.055   1.055  2021-09-14T13:27:00
# 1  2021-09-15T18:37:00   7.003   7.003  2021-09-15T18:37:00
# ...

# %% [markdown]
# ##### 6  Individual Market (stock, index, currency, commodity or bond)
# /markets/symbol/{symbol}
# https://api.tradingeconomics.com/markets/symbol/aapl:us?c=guest:guest

# %%
te.getMarketsBySymbol(symbols='aapl:us', output_type='df')
# Out:
#     Symbol Ticker   Name        Country                 Date    Type  \
# 0  AAPL:US   AAPL  Apple  United States  2021-09-17T14:46:00  stocks
#
#    decimals    Last   Close            CloseDate  ...  YTDChange  \
# 0       2.0  146.82  146.82  2021-09-17T14:46:00  ...      14.13
#
#   YTDPercentualChange  yesterday  lastWeek  lastMonth  lastYear  startYear  \
# 0             10.6489     148.79    148.97     146.36    106.84     132.69
#
#                              ISIN                     frequency  \
# 0  US0378331005                    Daily, Intraday, Live Stream
#
#             LastUpdate
# 0  2021-09-17T14:46:00
#
# [1 rows x 31 columns]

# %% [markdown]
# ##### 7 Multiple Markets
# /markets/symbol/{symbols}
# https://api.tradingeconomics.com/markets/symbol/aapl:us,indu:ind?c=guest:guest

# %%
te.getMarketsBySymbol(symbols=['aapl:us','indu:ind'], output_type='df')
# Out:
#      Symbol Ticker   Name        Country                 Date    Type  \
# 0   AAPL:US   AAPL  Apple  United States  2021-09-17T14:46:00  stocks
# 1  INDU:IND   INDU   US30  United States  2021-09-17T14:46:00   index
#
#    decimals         Last        Close            CloseDate  ...   YTDChange  \
# 0       2.0    146.82000    146.82000  2021-09-17T14:46:00  ...    14.13000
# 1       0.0  34427.78906  34427.78906  2021-09-17T14:44:00  ...  3821.30906
#
#   YTDPercentualChange  yesterday  lastWeek  lastMonth  lastYear  startYear  \
# 0             10.6489     148.79    148.97     146.36    106.84     132.69
# 1             12.4853   34751.32  34607.72   34960.69  27657.42   30606.48
#
#                              ISIN                     frequency  \
# 0  US0378331005                    Daily, Intraday, Live Stream
# 1                            None  Daily, Intraday, Live Stream
#
#             LastUpdate
# 0  2021-09-17T14:46:00
# 1  2021-09-17T14:46:00
#
# [2 rows x 31 columns]

# %% [markdown]
# ##### 8 List of stocks by country
# /markets/country/{country}
# https://api.tradingeconomics.com/markets/country/united%20states?client=guest:guest

# %%
te.getMarketsSearch(country='united states', output_type='df')
# Out:
#          Symbol                Ticker    Name        Country  \
# 0       SPX:IND                   SPX   US500  United States
# 1  USGG10YR:IND              USGG10YR  US 10Y  united states
# 2   USGG12M:IND  UNITEDSTA52WEEBILYIE  US 52W  united states
# 3    USGG1M:IND   UNITEDSTA4WEEBILYIE   US 1M  united states
# 4   USGG2YR:IND   UNITEDSTA2YEANOTYIE   US 2Y  united states
# 5    USGG3M:IND   UNITEDSTA3MONBILYIE   US 3M  united states
# 6    USGG3Y:IND   UNITEDSTA3YEANOTYIE   US 3Y  united states
# 7   USGG5YR:IND   UNITEDSTA5YEANOTYIE   US 5Y  united states
# 8    USGG6M:IND   UNITEDSTA6MONBILYIE   US 6M  united states
# 9    USGG7Y:IND   UNITEDSTA7YEANOTYIE   US 7Y  united states
#
#                   Date   Type  decimals       Last      Close  \
# 0  2021-09-17T14:49:00  index       2.0  4430.7700  4430.7700
# 1  2021-09-17T14:48:00   bond       4.0     1.3804     1.3804
# 2  2021-09-17T10:13:00   bond       4.0     0.0735     0.0735
# ...

# %% [markdown]
# ##### 9 A snapshot of latest peers prices by market
# /markets/peers/{symbol}
# https://api.tradingeconomics.com/markets/peers/aapl:us?c=guest:guest

# %%
te.getMarketsPeers(symbols='aapl:us', output_type='df')
# Out:
#       Symbol  Ticker                    Name        Country  \
# 0    6758:JP    6758                    Sony          Japan
# 1    AAPL:US    AAPL                   Apple  United States
# 2     ADI:US  ADI:US          Analog Devices  United States
# 3    AMAT:US    AMAT       Applied Materials  United States
# 4     AMD:US     AMD  Advanced Micro Devices  United States
# 5    AMZN:US    AMZN                  Amazon  United States
# 6    ANET:US    ANET         Arista Networks  United States
# 7     APH:US     APH                Amphenol  United States
# 8    AVGO:US    AVGO      Avago Technologies      Singapore
# 9   CCMP:IND    CCMP                  NASDAQ  United States
# 10  INDU:IND    INDU                    US30  United States
# 11   NDX:IND     NDX                   USNDX  United States
# 12   SPX:IND     SPX                   US500  United States
#
#                    Date    Type  decimals        Last       Close  \
# ...

# %% [markdown]
# ##### 10 Stock Market Index Components
# /markets/components/{symbol}
# https://api.tradingeconomics.com/markets/components/psi20:ind?c=guest:guest

# %%
te.getMarketsComponents(symbols=['psi20:ind'], output_type='df')
# Out:
#     Symbol  Ticker               Name   Country                 Date    Type  \
# 0  ALTR:PL    ALTR              Altri  Portugal  2021-09-17T00:00:00  stocks
# 1   BCP:PL  BCP:PL                BCP  Portugal  2021-09-17T00:00:00  stocks
# 2   COR:PL  COR:PL  Corticeira Amorim  Portugal  2021-09-17T14:48:00  stocks
# 3   CTT:PL  CTT:PL                CTT  Portugal  2021-09-17T00:00:00  stocks
# 4   EDP:PL     EDP                EDP  Portugal  2021-09-17T14:48:00  stocks
# 5  EDPR:PL    EDPR     EDP Renovaveis     Spain  2021-09-17T14:47:00  stocks
# 6   EGL:PL  EGL:PL         Mota Engil  Portugal  2021-09-17T00:00:00  stocks
# 7  GALP:PL    GALP               Galp  Portugal  2021-09-17T00:00:00  stocks
# 8   IBS:PL     IBS            Ibersol  Portugal  2021-09-17T00:00:00  stocks
# 9   JMT:PL     JMT   Jeronimo Martins  Portugal  2021-09-17T00:00:00  stocks
#
#    decimals     Last    Close            CloseDate  ...  YTDChange  \
# ...

# %% [markdown]
# ## Search

# %% [markdown]
# ##### 11 Search method
# /markets/search/{term}
# https://api.tradingeconomics.com/markets/search/united%20states?c=guest:guest

# %%
te.getMarketsSearch(country='united states', output_type='df')
# Out:
#          Symbol                Ticker    Name        Country  \
# 0       SPX:IND                   SPX   US500  United States
# 1  USGG10YR:IND              USGG10YR  US 10Y  united states
# 2   USGG12M:IND  UNITEDSTA52WEEBILYIE  US 52W  united states
# 3    USGG1M:IND   UNITEDSTA4WEEBILYIE   US 1M  united states
# 4   USGG2YR:IND   UNITEDSTA2YEANOTYIE   US 2Y  united states
# 5    USGG3M:IND   UNITEDSTA3MONBILYIE   US 3M  united states
# 6    USGG3Y:IND   UNITEDSTA3YEANOTYIE   US 3Y  united states
# 7   USGG5YR:IND   UNITEDSTA5YEANOTYIE   US 5Y  united states
# 8    USGG6M:IND   UNITEDSTA6MONBILYIE   US 6M  united states
# 9    USGG7Y:IND   UNITEDSTA7YEANOTYIE   US 7Y  united states
#
#                   Date   Type  decimals       Last      Close  \
# 0  2021-09-17T14:49:00  index       2.0  4430.7700  4430.7700
# 1  2021-09-17T14:48:00   bond       4.0     1.3804     1.3804
# 2  2021-09-17T10:13:00   bond       4.0     0.0735     0.0735
# ...

# %% [markdown]
# ##### 12 Filtering by Category
# /markets/search/{term}?category={category}
# https://api.tradingeconomics.com/markets/search/united%20states?c=guest:guest&category=index,markets

# %%
te.getMarketsSearch(country='united states', category=['index','markets'], output_type='df')
# Out:
#       Symbol Ticker                    Name        Country  \
# 0   CCMP:IND   CCMP                  NASDAQ  United States
# 1   INDU:IND   INDU                    US30  United States
# 2    MID:IND    MID                   US400  United States
# 3    NDX:IND    NDX                   USNDX  United States
# 4    SPX:IND    SPX                   US500  United States
# 5     USM:US    USM  United States Cellular  United States
# 6     USO:US    USO  United States Oil Fund  United States
# 7    VIX:IND    VIX                   USVIX  United States
# 8  W5000:IND  W5000                  US5000  United States
# 9       X:US   X:US     United States Steel  United States
#
#                   Date    Type  decimals        Last       Close  \
# 0  2021-09-17T14:29:00   index       0.0  15088.9736  15088.9736
# 1  2021-09-17T14:49:00   index       0.0  34451.7900  34451.7900
# 2  2021-09-17T14:33:00   index       0.0   2681.8400   2681.8400
# ...

# %% [markdown]
# ## Historical

# %% [markdown]
# ##### 13 - Historical Data for 1 instrument
# /markets/historical/{symbol}
# https://api.tradingeconomics.com/markets/historical/aapl:us?c=guest:guest

# %%
te.fetchMarkets(symbol='aapl:us', output_type='df')
# Out:
#              symbol    open    high        low   close
# 2021-09-17  AAPL:US  148.82  148.82  146.64999  146.69
# 2021-09-16  AAPL:US  148.44  148.97  147.22100  148.79
# 2021-09-15  AAPL:US  148.56  149.44  146.37000  149.03
# 2021-09-14  AAPL:US  150.35  151.07  146.91000  148.12
# 2021-09-13  AAPL:US  150.63  151.42  148.75000  149.55
# 2021-09-10  AAPL:US  155.00  155.48  148.70000  148.97
# 2021-09-09  AAPL:US  155.49  156.11  153.95000  154.07
# 2021-09-08  AAPL:US  156.98  157.04  153.97500  155.11
# 2021-09-07  AAPL:US  154.97  157.26  154.39000  156.69
# 2021-09-03  AAPL:US  153.76  154.63  153.09000  154.30

# %% [markdown]
# ##### 13 Historical Data for multiple instruments
# /markets/historical/{symbols}
# https://api.tradingeconomics.com/markets/historical/aapl:us,indu:ind?c=guest:guest

# %%
te.fetchMarkets(symbol=['aapl:us','indu:ind'], output_type='df')
# Out:
#               symbol      open      high          low        close
# 2021-09-17  INDU:IND  34737.86  34779.86  34418.78906  34421.78906
# 2021-09-17   AAPL:US    148.82    148.82    146.64999    146.69000
# 2021-09-16   AAPL:US    148.44    148.97    147.22100    148.79000
# 2021-09-16  INDU:IND  34810.27  34943.55  34540.11000  34751.32000
# 2021-09-15  INDU:IND  34580.95  34880.77  34522.03000  34814.39000
# 2021-09-15   AAPL:US    148.56    149.44    146.37000    149.03000
# 2021-09-14   AAPL:US    150.35    151.07    146.91000    148.12000
# 2021-09-14  INDU:IND  34906.90  34990.36  34510.30000  34577.57000
# 2021-09-13  INDU:IND  34665.50  34939.10  34665.50000  34869.63000
# 2021-09-13   AAPL:US    150.63    151.42    148.75000    149.55000

# %% [markdown]
# ##### 14 Filter historical data by date
# /markets/historical/{symbol}?d1=yyyy-mm-dd&d2=yyyy-mm-dd
# https://api.tradingeconomics.com/markets/historical/aapl:us?c=guest:guest&d1=2017-08-01&d2=2017-08-08

# %%
te.fetchMarkets(symbol=['aapl:us','indu:ind'], initDate = '2017-01-01', endDate = '2017-06-15',output_type='df')
# Out:
#               symbol      open      high          low        close
# 2021-09-17  INDU:IND  34737.86  34779.86  34418.78906  34445.78906
# 2021-09-17   AAPL:US    148.82    148.82    146.64999    146.69000
# 2021-09-16   AAPL:US    148.44    148.97    147.22100    148.79000
# 2021-09-16  INDU:IND  34810.27  34943.55  34540.11000  34751.32000
# 2021-09-15  INDU:IND  34580.95  34880.77  34522.03000  34814.39000
# 2021-09-15   AAPL:US    148.56    149.44    146.37000    149.03000
# 2021-09-14   AAPL:US    150.35    151.07    146.91000    148.12000
# 2021-09-14  INDU:IND  34906.90  34990.36  34510.30000  34577.57000
# 2021-09-13  INDU:IND  34665.50  34939.10  34665.50000  34869.63000
# 2021-09-13   AAPL:US    150.63    151.42    148.75000    149.55000

# %% [markdown]
# ## Intraday

# %% [markdown]
# ##### 15 Intraday prices for a single instrument
# /markets/intraday/{symbol}
# https://api.tradingeconomics.com/markets/intraday/aapl:us?c=guest:guest

# %%
te.getMarketsIntraday(symbols='aapl:us', output_type='df')
# Out:
#       Symbol                 Date       Open       High        Low      Close
# 0    AAPL:US  2021-09-17T14:54:00  146.78000  146.78999  146.77000  146.78999
# 1    AAPL:US  2021-09-17T14:53:00  146.63000  146.75000  146.63000  146.75000
# 2    AAPL:US  2021-09-17T14:52:00  146.67999  146.72000  146.63000  146.63000
# 3    AAPL:US  2021-09-17T14:51:00  146.62000  146.64999  146.60001  146.64999
# 4    AAPL:US  2021-09-17T14:49:00  146.70000  146.73000  146.67999  146.72000
# ..       ...                  ...        ...        ...        ...        ...
# 995  AAPL:US  2021-09-14T17:23:00  148.88000  148.88000  148.77000  148.77000
# 996  AAPL:US  2021-09-14T17:22:00  148.77000  148.88000  148.77000  148.86000
# 997  AAPL:US  2021-09-14T17:21:00  148.78000  148.80000  148.75999  148.78000
# 998  AAPL:US  2021-09-14T17:20:00  148.78999  148.78999  148.77000  148.78000
# 999  AAPL:US  2021-09-14T17:19:00  148.75999  148.84000  148.74001  148.78999
#
# [1000 rows x 6 columns]

# %% [markdown]
# ##### Filter 16 intraday prices by date and hour
# /markets/intraday/{symbol}?d1=yyyy-mm-dd hh:mm
# https://api.tradingeconomics.com/markets/intraday/aapl:us?c=guest:guest&d1=2017-08-10%2015:30

# %%
te.getMarketsIntraday(symbols = 'indu:ind', initDate='2018-03-13 15:30', output_type='df')
# Out:
#      Symbol                 Date         Open         High          Low  \
# 0  INDU:IND  2021-09-17T14:53:00  34423.78906  34450.78906  34418.78906
# 1  INDU:IND  2021-09-17T14:52:00  34424.78906  34433.78906  34418.78906
# 2  INDU:IND  2021-09-17T14:51:00  34417.78906  34429.78906  34414.78906
# 3  INDU:IND  2021-09-17T14:50:00  34443.78906  34443.78906  34413.78906
# 4  INDU:IND  2021-09-17T14:49:00  34450.78906  34450.78906  34435.78906
# 5  INDU:IND  2021-09-17T14:48:00  34426.78906  34451.78906  34424.78906
# 6  INDU:IND  2021-09-17T14:47:00  34416.78906  34425.78906  34409.78125
# 7  INDU:IND  2021-09-17T14:46:00  34421.78906  34426.78906  34411.78125
# 8  INDU:IND  2021-09-17T14:45:00  34423.78906  34428.78906  34416.78906
# 9  INDU:IND  2021-09-17T14:44:00  34438.78906  34443.78906  34425.78906
#
#          Close
# 0  34448.78906
# 1  34422.78906
# 2  34422.78906
# 3  34418.78906
# 4  34442.78906
# 5  34450.78906
# 6  34424.78906
# 7  34418.78906
# 8  34420.78906
# ...

# %% [markdown]
# ##### 17 Filter intraday prices by date
# /markets/intraday/{symbol}?d1=yyyy-mm-dd&d2=yyyy-mm-dd
# https://api.tradingeconomics.com/markets/intraday/aapl:us?c=guest:guest&d1=2017-08-01&d2=2017-08-08

# %%
te.getMarketsIntraday(symbols = ['aapl:us', 'indu:ind'], initDate='2018-03-13', endDate='2018-04-01', output_type = 'df')
# Out:
#      Symbol                 Date         Open         High          Low  \
# 0   AAPL:US  2021-09-17T14:55:00    146.84000    146.87000    146.83000
# 1  INDU:IND  2021-09-17T14:55:00  34451.78906  34453.78906  34429.78906
# 2   AAPL:US  2021-09-17T14:54:00    146.78000    146.85001    146.77000
# 3  INDU:IND  2021-09-17T14:54:00  34451.78906  34459.78906  34437.78906
# 4   AAPL:US  2021-09-17T14:53:00    146.63000    146.75000    146.63000
# 5  INDU:IND  2021-09-17T14:53:00  34423.78906  34450.78906  34418.78906
# 6   AAPL:US  2021-09-17T14:52:00    146.67999    146.72000    146.63000
# 7  INDU:IND  2021-09-17T14:52:00  34424.78906  34433.78906  34418.78906
# 8   AAPL:US  2021-09-17T14:51:00    146.62000    146.64999    146.60001
# 9  INDU:IND  2021-09-17T14:51:00  34417.78906  34429.78906  34414.78906
#
#          Close
# 0    146.87000
# 1  34430.78906
# 2    146.85001
# 3  34454.78906
# 4    146.75000
# 5  34448.78906
# 6    146.63000
# 7  34422.78906
# 8    146.64999
# ...

# %% [markdown]
# ##### 18 Aggregate intraday prices by interval - allowed intervals: 1m, 5m, 10m, 15m, 30m, 1h, 2h, 4h
# /markets/intraday/{symbol}?agr={interval}&d1=yyyy-mm-dd&d2=yyyy-mm-dd

# %% [markdown]
# http://api.tradingeconomics.com//markets/intraday/CL1:COM?agr=1m&d1=2021-01-01%2000:00&d2=2021-12-01%2015:30&client=guest:guest

# %%
te.getMarketsIntradayByInterval(symbol='CL1:COM',interval='1m',initDate='2021-01-01',endDate='2021-12-01',output_type='df')
# Out:
#     Symbol                 Date   Open   High    Low  Close
# 0  CL1:COM  2021-09-21T13:37:00  70.74  70.74  70.67  70.69
# 1  CL1:COM  2021-09-21T13:36:00  70.78  70.82  70.72  70.75
# 2  CL1:COM  2021-09-21T13:35:00  70.82  70.85  70.78  70.79
# 3  CL1:COM  2021-09-21T13:34:00  70.84  70.86  70.79  70.81
# 4  CL1:COM  2021-09-21T13:33:00  70.77  70.87  70.71  70.83
# 5  CL1:COM  2021-09-21T13:32:00  70.77  70.82  70.58  70.76
# 6  CL1:COM  2021-09-21T13:31:00  70.78  70.83  70.73  70.76
# 7  CL1:COM  2021-09-21T13:30:00  70.84  70.84  70.75  70.79
# 8  CL1:COM  2021-09-21T13:29:00  70.77  70.87  70.77  70.85

# %% [markdown]
# ## Forecasts

# %% [markdown]
# ##### 19  Market forecasts for major stock market indexes
# /markets/forecasts/index
# http://api.tradingeconomics.com/markets/forecasts/index?c=guest:guest

# %%
te.getMarketsForecasts(category = 'index', output_type='df')
# Out:
#         Symbol     Country                 Date   Type        Last  Url  \
# 0   TA-125:IND      Israel  2021-09-14T14:14:00  index     1862.53  NaN
# 1   TEDPIX:IND        Iran  2021-09-15T00:00:00  index  1488212.00  NaN
# 2   BGSMDC:IND    Botswana  2021-09-16T00:00:00  index     6848.31  NaN
# 3      BSX:IND     Bermuda  2021-09-16T00:00:00  index     2568.92  NaN
# 4     BVQA:IND     Ecuador  2021-09-16T00:00:00  index     1262.59  NaN
# 5  CRSMBCT:IND  Costa Rica  2021-09-16T00:00:00  index    11907.13  NaN
# 6      DSM:IND       Qatar  2021-09-16T00:00:00  index    11180.92  NaN
# 7    INDZI:IND    Zimbabwe  2021-09-16T00:00:00  index    22734.73  NaN
# 8  KNSMIDX:IND       Kenya  2021-09-16T00:00:00  index     2051.80  NaN
# 9    MONEX:IND  Montenegro  2021-09-16T00:00:00  index    10992.60  NaN
#
#    Importance     Forecast1     Forecast2     Forecast3     Forecast4
# 0         400  1.811290e+03  1.768244e+03  1.726125e+03  1.684934e+03
# ...

# %% [markdown]
# ##### 20 Market forecasts for major exchange rates
# /markets/forecasts/currency
# http://api.tradingeconomics.com/markets/forecasts/currency?c=guest:guest

# %%
te.getMarketsForecasts(category = 'currency', output_type='df')
# Out:
#        Symbol               Country                 Date      Type  \
# 0  AUDUSD:CUR             australia  2021-09-17T14:58:00  currency
# 1  BTCUSD:CUR                 Other  2021-09-17T14:57:00  currency
# 2     DXY:CUR         United States  2021-09-17T14:57:00  currency
# 3  EURUSD:CUR             euro area  2021-09-17T14:58:00  currency
# 4  GBPUSD:CUR        united kingdom  2021-09-17T14:58:00  currency
# 5  NZDUSD:CUR           new zealand  2021-09-17T14:58:00  currency
# 6  USDAED:CUR  united arab emirates  2021-09-17T14:52:00  currency
# 7  USDAFN:CUR           afghanistan  2021-09-17T14:52:00  currency
# 8  USDALL:CUR               albania  2021-09-17T14:52:00  currency
# 9  USDAMD:CUR               armenia  2021-09-17T14:26:00  currency
#
#           Last  Url  Importance     Forecast1     Forecast2     Forecast3  \
# 0      0.72702  NaN           3      0.729716      0.724572      0.719501
# 1  47520.89000  NaN           4  43397.127110  41033.384762  38793.521482
# ...

# %% [markdown]
# ##### 21 Market forecasts for major commodities
# /markets/forecasts/commodity
# http://api.tradingeconomics.com/markets/forecasts/commodity?c=guest:guest

# %%
te.getMarketsForecasts(category = 'commodity', output_type='df')
# Out:
#          Symbol    Country                 Date       Type       Last  Url  \
# 0      BEEF:COM  commodity  2021-09-16T00:00:00  commodity     20.410  NaN
# 1       CHE:COM  commodity  2021-09-16T00:00:00  commodity      1.646  NaN
# 2     CRYTR:IND  commodity  2021-09-16T00:00:00  commodity    238.016  NaN
# 3       DL1:COM  commodity  2021-09-16T00:00:00  commodity      2.207  NaN
# 4       GAC:COM  Commodity  2021-09-16T00:00:00  commodity   1925.000  NaN
# 5  GECNYBGQ:COM  Commodity  2021-09-16T00:00:00  commodity   8650.000  NaN
# 6       IMR:COM  commodity  2021-09-16T00:00:00  commodity     34.500  NaN
# 7       IUC:COM  Commodity  2021-09-16T00:00:00  commodity   1700.000  NaN
# 8      LCO1:COM  commodity  2021-09-16T00:00:00  commodity  51500.000  NaN
# 9       LL1:COM  commodity  2021-09-16T00:00:00  commodity   2202.750  NaN
#
#    Importance     Forecast1     Forecast2     Forecast3     Forecast4
# 0         999     20.075850     19.903725     19.731600     19.561500
# ...

# %% [markdown]
# ##### 22 Market forecasts for major bonds
# /markets/forecasts/bond
# http://api.tradingeconomics.com/markets/forecasts/bond?c=guest:guest

# %%
te.getMarketsForecasts(category = 'bond', output_type='df')
# Out:
#              Symbol    Country                 Date  Type    Last  Url  \
# 0      GISR10YR:GOV     israel  2021-09-14T13:27:00  bond   1.055  NaN
# 1      GMXN10YR:IND     mexico  2021-09-15T18:37:00  bond   7.003  NaN
# 2    BGRGOVB10Y:GOV   bulgaria  2021-09-16T00:00:00  bond   0.300  NaN
# 3  CHLGOVBON10Y:GOV      chile  2021-09-16T00:00:00  bond   5.310  NaN
# 4  LTUGOVBON10Y:GOV  Lithuania  2021-09-16T00:00:00  bond   0.069  NaN
# 5  LVAGOVBON10Y:GOV     latvia  2021-09-16T00:00:00  bond   0.549  NaN
# 6  NGAGOVBON10Y:GOV    nigeria  2021-09-16T00:00:00  bond  11.942  NaN
# 7        RUGE1M:GOV     Russia  2021-09-16T00:00:00  bond   6.650  NaN
# 8        RUGE3M:GOV     Russia  2021-09-16T00:00:00  bond   6.850  NaN
# 9        RUGE6M:GOV     Russia  2021-09-16T00:00:00  bond   7.070  NaN
#
#    Importance  Forecast1  Forecast2  Forecast3  Forecast4
# 0         999   1.113845   1.155194   1.198047   1.242511
# 1         999   7.052629   7.148649   7.246061   7.344169
# ...

# %% [markdown]
# ##### 23 Get major market forecasts by symbol
# /markets/forecasts/symbol/{symbols}
# http://api.tradingeconomics.com/markets/forecasts/symbol/BULGARIAGOVB10Y:GOV,LITHUANIAGOVBON10Y:GOV,GBGB10YR:GOV?c=guest:guest

# %%
te.getMarketsForecasts(symbol = ['psi20:ind', 'indu:ind'], output_type = 'df')
# Out:
#      Symbol        Country                 Date    Type      Last  Url  \
# 0   AAPL:US  United States  2021-09-17T15:01:00  stocks    146.73  NaN
# 1   DAX:IND        Germany  2021-09-17T15:00:00   index  15472.50  NaN
# 2  INDU:IND  United States  2021-09-17T15:00:00   index  34421.79  NaN
#
#    Importance     Forecast1     Forecast2     Forecast3     Forecast4
# 0         500    145.546368    142.373457    139.269716    136.233636
# 1          70  15125.575227  14707.105646  14299.525608  13902.835113
# 2           1  33900.998082  33162.814419  32438.493360  31731.500556

# %% [markdown]
# ## Earnings

# %% [markdown]
# ##### 24 Default earnings calendar
# /earnings
# https://api.tradingeconomics.com/earnings?c=guest:guest

# %%
te.getEarnings(output_type='df')
# Out:
#                   Date     Symbol                             Name      Type  \
# 0  2021-09-15T00:00:00     JKS:US  JinkoSolar Holding Co. Ltd. ADR  Earnings
# 1  2021-09-15T00:00:00     WUG:GR                Westag&Getalit ST  Earnings
# 2  2021-09-15T00:00:00     RDW:LN                           Redrow  Earnings
# 3  2021-09-15T00:00:00    VIRC:US                            Virco  Earnings
# 4  2021-09-15T00:00:00    ROTH:FP                    PARIS ORLEANS  Earnings
# 5  2021-09-15T00:00:00     TPE:PW            TAURON Polska Energia  Earnings
# 6  2021-09-15T00:00:00     ITX:SM                          Inditex  Earnings
# 7  2021-09-15T00:00:00    3282:JP                     Comforia Res  Earnings
# 8  2021-09-15T00:00:00  RIPLEY:CI                      Ripley Corp  Earnings
# 9  2021-09-15T00:00:00     RTN:LN                 Restaurant Group  Earnings
#
#     Actual Forecast FiscalTag FiscalReference CalendarReference  \
# ...

# %% [markdown]
# ##### 25 Filter earnings calendar by date
# /earnings?d1=yyyy-mm-dd
# https://api.tradingeconomics.com/earnings?c=guest:guest&d1=2017-01-01

# %%
te.getEarnings(initDate='2016-01-01', output_type='df')
# Out:
#                   Date   Symbol                   Name      Type Actual  \
# 0  2016-01-05T00:00:00  LNDC:US                 Landec  Earnings   0.07
# 1  2016-01-05T00:00:00   CMC:US      Commercial Metals  Earnings   0.15
# 2  2016-01-05T00:00:00  SONC:US                  Sonic  Earnings   0.18
# 3  2016-01-06T00:00:00    MG:US                Mistras  Earnings   0.39
# 4  2016-01-06T00:00:00   UNF:US               UniFirst  Earnings   1.78
# 5  2016-01-06T00:00:00   MON:US               Monsanto  Earnings  -0.11
# 6  2016-01-06T00:00:00   MSM:US  Msc Industrial Direct  Earnings    0.8
# 7  2016-01-06T00:00:00   RPM:US      Rpm International  Earnings   0.14
# 8  2016-01-06T00:00:00  RECN:US   Resources Connection  Earnings   0.23
# 9  2016-01-07T00:00:00  FINL:US            Finish Line  Earnings  -0.07
#
#   Forecast FiscalTag FiscalReference CalendarReference        Country  \
# 0     None  FY2016Q2           Q2/16            2015/9  United States
# ...

# %% [markdown]
# ##### 26 Filter earnings calendar by instrument and date
# /earnings/symbol/{symbol}?d1=yyyy-mm-dd
# https://api.tradingeconomics.com/earnings/symbol/aapl:us?c=guest:guest&d1=2017-01-01

# %%
te.getEarnings(symbols='aapl:us',initDate='2016-01-01', output_type='df')
# Out:
#                   Date   Symbol   Name      Type Actual Forecast FiscalTag  \
# 0  2016-01-26T00:00:00  AAPL:US  Apple  Earnings   3.28     None  FY2016Q1
# 1  2016-04-26T00:00:00  AAPL:US  Apple  Earnings    1.9     None  FY2016Q2
# 2  2016-07-26T00:00:00  AAPL:US  Apple  Earnings   1.42     None  FY2016Q3
# 3  2016-10-25T00:00:00  AAPL:US  Apple  Earnings   1.67     None  FY2016Q4
# 4  2017-01-31T00:00:00  AAPL:US  Apple  Earnings   3.36     None  FY2017Q1
# 5  2017-05-02T00:00:00  AAPL:US  Apple  Earnings    2.1     None  FY2017Q2
# 6  2017-08-01T00:00:00  AAPL:US  Apple  Earnings   1.67     None  FY2017Q3
# 7  2017-11-02T00:00:00  AAPL:US  Apple  Earnings   2.07     1.87  FY2017Q4
# 8  2018-02-01T00:00:00  AAPL:US  Apple  Earnings   3.89     3.85  FY2018Q1
# 9  2018-05-01T00:00:00  AAPL:US  Apple  Earnings   2.73     2.69  FY2018Q2
#
#   FiscalReference CalendarReference        Country Currency  Session  \
# 0           Q1/16           2015/12  United States      USD     21.0
# ...

# %% [markdown]
# ##### 27 /earnings/symbol/{symbol}?d1=yyyy-mm-dd&d2=yyyy-mm-dd
#
# https://api.tradingeconomics.com/earnings/symbol/msft:us?c=guest:guest&d1=2016-01-01&d2=2017-12-31

# %%
te.getEarnings(symbols = 'msft:us', initDate='2016-01-01', endDate='2017-12-31', output_type='df')
# Out:
#                   Date   Symbol   Name      Type Actual Forecast FiscalTag  \
# 0  2016-01-26T00:00:00  AAPL:US  Apple  Earnings   3.28     None  FY2016Q1
# 1  2016-04-26T00:00:00  AAPL:US  Apple  Earnings    1.9     None  FY2016Q2
# 2  2016-07-26T00:00:00  AAPL:US  Apple  Earnings   1.42     None  FY2016Q3
# 3  2016-10-25T00:00:00  AAPL:US  Apple  Earnings   1.67     None  FY2016Q4
# 4  2017-01-31T00:00:00  AAPL:US  Apple  Earnings   3.36     None  FY2017Q1
# 5  2017-05-02T00:00:00  AAPL:US  Apple  Earnings    2.1     None  FY2017Q2
# 6  2017-08-01T00:00:00  AAPL:US  Apple  Earnings   1.67     None  FY2017Q3
# 7  2017-11-02T00:00:00  AAPL:US  Apple  Earnings   2.07     1.87  FY2017Q4
#
#   FiscalReference CalendarReference        Country Currency  Session  \
# 0           Q1/16           2015/12  United States      USD     21.0
# 1           Q2/16            2016/3  United States      USD     21.0
# 2           Q3/16            2016/6  United States      USD     21.0
# ...

# %% [markdown]
# ##### 28 Filter earnings calendar by country
# /earnings/country/{country}
# https://api.tradingeconomics.com/earnings/country/united%20states?c=guest:guest

# %%
te.getEarnings(country = 'united states', output_type='df')
# Out:
#                   Date   Symbol                             Name      Type  \
# 0  2021-09-15T00:00:00  IPHA:US                    Innate Pharma  Earnings
# 1  2021-09-15T00:00:00  VIRC:US                            Virco  Earnings
# 2  2021-09-15T00:00:00   JKS:US  JinkoSolar Holding Co. Ltd. ADR  Earnings
# 3  2021-09-15T00:00:00   AXR:US                            Amrep  Earnings
# 4  2021-09-15T00:00:00  SGMA:US                        SigmaTron  Earnings
# 5  2021-09-16T00:00:00  CUSI:US                Cuisine Solutions  Earnings
# 6  2021-09-16T00:00:00  FONR:US                            Fonar  Earnings
# 7  2021-09-16T00:00:00  PCYG:US                        Park City  Earnings
# 8  2021-09-16T00:00:00  CODA:US                     Coda Octopus  Earnings
# 9  2021-09-16T00:00:00   IHT:US            InnSuites Hospitality  Earnings
#
#   Actual Forecast FiscalTag FiscalReference CalendarReference        Country  \
# ...

# %% [markdown]
# ## Financials

# %% [markdown]
# ##### Financials companies list.
# /financials/companies
# http://api.tradingeconomics.com/financials/companies?c=guest:guest

# %%
te.getFinancialsData(output_type='df')
# Out:
#      Symbol                          Name    Country
# 0   ARCO:US                 Arcos Dorados  Argentina
# 1   IRCP:US  Irsa Propiedades Comerciales  Argentina
# 2    BFR:US            Bbva Banco Frances  Argentina
# 3    YPF:US                           YPF  Argentina
# 4    BMA:US                   Banco Macro  Argentina
# 5  CRESY:US              Cresud Sacif Y A  Argentina
# 6    EDN:US                        Edenor  Argentina
# 7   GGAL:US      Grupo Financiero Galicia  Argentina
# 8   MELI:US                  MERCADOLIBRE  Argentina
# 9    PAM:US                 Pampa Energia  Argentina

# %% [markdown]
# ##### 30 Financials companies list filtered by country.
# /financials/companies?country={country}
# http://api.tradingeconomics.com/financials/companies?country=united%20states&c=guest:guest

# %%
te.getFinancialsData(country='united states',output_type='df')
# Out:
#     Symbol                     Name        Country
# 0     A:US                  Agilent  United States
# 1    AA:US                    Alcoa  United States
# 2   AAL:US        American Airlines  United States
# 3   AAN:US                   Aarons  United States
# 4  AAOI:US  Applied Optoelectronics  United States
# 5  AAON:US                     Aaon  United States
# 6   AAP:US       Advance Auto Parts  United States
# 7  AAPL:US                    Apple  United States
# 8   AAT:US          American Assets  United States
# 9  AAWW:US      Atlas Air Worldwide  United States

# %% [markdown]
# ##### 31 Financials companies list filtered by more than one country (MAX countries = 5).
# /financials/companies?country={countries}
# http://api.tradingeconomics.com/financials/companies?country=spain,germany&c=guest:guest

# %%
te.getFinancialsData(country=['brazil', 'germany'],output_type='df')
# Out:
#       Symbol                                Name Country
# 0   ABEV3:BS                               Ambev  Brazil
# 1    ABEV:US                               Ambev  Brazil
# 2   ABCB4:BZ                 Banco ABC Brasil SA  Brazil
# 3   AALR3:BZ          Alliar Medicos A Frente SA  Brazil
# 4  ALUP11:BZ                       Alupar Invest  Brazil
# 5   ALSO3:BZ  Aliansce Sonae Shopping Centers SA  Brazil
# 6   AGRO3:BZ                         Brasil Agro  Brazil
# 7   AMAR3:BZ                     Marisa Lojas SA  Brazil
# 8   ARZZ3:BZ     Arezzo Industria  e Comercio SA  Brazil
# 9   B3SA3:BZ                 Brasil Bolsa Balcao  Brazil

# %% [markdown]
# ##### 32 Financials data by stock symbol
# /financials/symbol/{symbol}
# http://api.tradingeconomics.com/financials/symbol/aapl:us?c=guest:guest

# %%
te.getFinancialsData(symbol='aapl:us',output_type='df')
# Out:
#                         Symbol                 Date        last      value1  \
# 0               aapl:us:assets  2021-06-30T00:00:00  329840.000  329840.000
# 1  aapl:us:cash-and-equivalent  2021-06-30T00:00:00   19197.000   19197.000
# 2        aapl:us:cost-of-sales  2021-06-30T00:00:00   46179.000   46179.000
# 3       aapl:us:current-assets  2021-06-30T00:00:00  114423.000  114423.000
# 4  aapl:us:current-liabilities  2021-06-30T00:00:00  107754.000  107754.000
# 5                 aapl:us:debt  2021-06-30T00:00:00  121791.000  121791.000
# 6                   aapl:us:dy  2021-06-30T00:00:00       0.643       0.643
# 7                 aapl:us:ebit  2021-06-30T00:00:00   24126.000   24126.000
# 8               aapl:us:ebitda  2021-06-30T00:00:00   26958.000   26958.000
# 9            aapl:us:employees  2019-12-31T00:00:00  137000.000  137000.000
#
#                  date1      value2                date2      value3  \
# ...

# %% [markdown]
# ##### 33 Financials historical data
# /financials/historical/{symbol}
# http://api.tradingeconomics.com/financials/historical/aapl:us:assets?c=guest:guest

# %%
te.getHistoricalFinancials(symbol='aapl:us', category='assets', output_type='df')
# Out:
#     symbol                                           category  \
# 0  aapl:us  assets                                        ...
# 1  aapl:us  assets                                        ...
# 2  aapl:us  assets                                        ...
# 3  aapl:us  assets                                        ...
# 4  aapl:us  assets                                        ...
# 5  aapl:us  assets                                        ...
# 6  aapl:us  assets                                        ...
# 7  aapl:us  assets                                        ...
# 8  aapl:us  assets                                        ...
# 9  aapl:us  assets                                        ...
#
#                   date     value           reportDate   reference
# 0  2009-12-31T00:00:00   53926.0  2009-12-26T00:00:00  FY2010Q1
# 1  2010-03-31T00:00:00   57057.0  2010-03-27T00:00:00  FY2010Q2
# 2  2010-06-30T00:00:00   64725.0  2010-06-26T00:00:00  FY2010Q3
# ...
