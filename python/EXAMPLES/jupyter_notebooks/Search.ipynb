# %%
import tradingeconomics as te

# %%
te.login()
# Out:
# 'You are logged in as a guest:guest'

# %% [markdown]
# # Search

# %% [markdown]
# ##### List of categories available.
# /search/categories
# https://api.tradingeconomics.com/search/categories?c=guest:guest

# %%
te.getSearch(output_type='df')
# Out:
#                Categories
# 0                 Markets
# 1               Commodity
# 2                Currency
# 3                   Index
# 4                Economic
# 5                Comtrade
# 6          Worldbank - wb
# 7  Federal Reserve - fred

# %% [markdown]
# ##### Search for term/keyword by category.
# /search/{term}?category={category}
# https://api.tradingeconomics.com/search/japan?category=markets&c=guest:guest

# %%
te.getSearch(term='japan',category='markets',output_type='df')
# Out:
#        Symbol           Ticker       Name Country                 Date  \
# 0  GJGB10:IND           GJGB10  Japan 10Y   japan  2021-09-21T11:07:00
# 1  GJGB1M:IND           GJGB1M   Japan 1M   Japan  2021-09-21T09:40:00
# 2  GJGB1Y:IND           GJGB1Y  Japan 52W   Japan  2021-09-21T09:40:00
# 3  GJGB2Y:IND        JAPAN2YNY   Japan 2Y   Japan  2021-09-21T09:40:00
# 4  GJGB3M:IND           GJGB3M   Japan 3M   Japan  2021-09-21T09:40:00
# 5  GJGB3Y:IND           GJGB3Y   Japan 3Y   Japan  2021-09-21T13:33:00
# 6  GJGB5Y:IND  JAPAN5YEANOTYIE   Japan 5Y   Japan  2021-09-21T12:47:00
# 7  GJGB6M:IND           GJGB6M   Japan 6M   Japan  2021-09-21T09:40:00
# 8  GJGB7Y:IND           GJGB7Y   Japan 7Y   Japan  2021-09-21T13:36:00
# 9  USDJPY:CUR              JPY     USDJPY   japan  2021-09-21T13:39:00
#
#        Type  decimals       state     Last    Close  ... day_high  day_low  \
# 0      bond       4.0  OPEN          0.046    0.046  ...    0.047    0.037
# ...

# %% [markdown]
# ##### Search for term/keyword in all categories available.
# /search/{term}
# http://api.tradingeconomics.com/search/gold?c=guest:guest

# %%
te.getSearch(term='gold',output_type='df')
# Out:
#             Symbol
# 0      CHINAGOLRES
# 1   EUROAREAGOLRES
# 2    GERMANYGOLRES
# 3      JAPANGOLRES
# 4  UNITEDSTAGOLRES
# 5       XAUUSD:CUR
