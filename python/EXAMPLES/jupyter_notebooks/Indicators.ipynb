# %%
import tradingeconomics as te
te.login()
# Out:
# 'You are logged in as a guest:guest'

# %% [markdown]
# # Indicators

# %% [markdown]
# ##### 1 List of all indicators
# /indicators

# %% [markdown]
# https://api.tradingeconomics.com/indicators?c=guest:guest

# %%
te.getIndicatorData(output_type='df')
# Out:
# Without country indication only a list of available indicators will be returned...
#              Category CategoryGroup
# 0  1 Month Bill Yield       Markets
# 1   2 Year Note Yield       Markets
# 2  20 Year bond Yield       Markets
# 3  3 Month Bill Yield       Markets
# 4   3 Year Note Yield       Markets
# 5  30 Year bond-Yield       Markets
# 6   5 Year Note Yield       Markets
# 7  52 Week Bill Yield       Markets
# 8  6 Month Bill Yield       Markets
# 9   7 Year Note Yield       Markets

# %% [markdown]
# ##### 2 List of indicators by country
# /country/{country}

# %% [markdown]
# https://api.tradingeconomics.com/country/united%20states?c=guest:guest

# %%
te.getIndicatorData(country='united states', output_type='df')
# Out:
#          Country                    Category  \
# 0  United States          20 Year bond Yield
# 1  United States       ADP Employment Change
# 2  United States           API Crude Imports
# 3  United States  API Crude Oil Stock Change
# 4  United States              API Crude Runs
# 5  United States          API Cushing Number
# 6  United States       API Distillate Stocks
# 7  United States         API Gasoline Stocks
# 8  United States             API Heating Oil
# 9  United States         API Product Imports
#
#                                       Title  LatestValue      LatestValueDate  \
# 0          United States 20 Year bond Yield         2.00  2021-09-13T00:00:00
# 1       United States ADP Employment Change       374.00  2021-08-31T00:00:00
# 2           United States API Crude Imports        -0.27  2021-08-27T00:00:00
# 3  United States API Crude Oil Stock Change        -2.88  2021-09-03T00:00:00
# ...

# %% [markdown]
# ##### 3 List of indicators by country and group( you can check groups in the "categoryGroup" field of /indicators)
# /country/{country}?c=guest:guest&group={group}

# %% [markdown]
# http://api.tradingeconomics.com/country/united%20states?c=guest:guest&group=gdp

# %%
te.getIndicatorByCategoryGroup(country='united states', category_group='gdp', output_type='df')
# Out:
#          Country                        Category  \
# 0  United States                             GDP
# 1  United States          GDP Annual Growth Rate
# 2  United States             GDP Constant Prices
# 3  United States            GDP From Agriculture
# 4  United States           GDP From Construction
# 5  United States          GDP From Manufacturing
# 6  United States                 GDP From Mining
# 7  United States  GDP From Public Administration
# 8  United States               GDP From Services
# 9  United States              GDP From Transport
#
#                                                Title      LatestValueDate  \
# 0                                  United States GDP  2020-12-31T00:00:00
# 1               United States GDP Annual Growth Rate  2021-06-30T00:00:00
# 2                  United States GDP Constant Prices  2021-06-30T00:00:00
# 3  United States GDP From Agriculture Forestry Fi...  2021-03-31T00:00:00
# ...

# %% [markdown]
# ##### 4 Specific indicator for all countries
# /country/all/{indicator}

# %% [markdown]
# https://api.tradingeconomics.com/country/all/gdp?c=guest:guest

# %%
te.getIndicatorData(country='all', indicators='gdp', output_type='df')
# Out:
#                Country Category                    Title  LatestValue  \
# 0          Afghanistan      GDP          Afghanistan GDP        19.81
# 1              Albania      GDP              Albania GDP        14.80
# 2              Algeria      GDP              Algeria GDP       145.16
# 3              Andorra      GDP              Andorra GDP         3.16
# 4               Angola      GDP               Angola GDP        62.31
# 5  Antigua And Barbuda      GDP  Antigua And Barbuda GDP         1.42
# 6            Argentina      GDP            Argentina GDP       383.10
# 7              Armenia      GDP              Armenia GDP        12.65
# 8                Aruba      GDP                Aruba GDP         3.20
# 9            Australia      GDP            Australia GDP      1330.90
#
#        LatestValueDate      Source         Unit                       URL  \
# 0  2020-12-31T00:00:00  World Bank  USD Billion          /afghanistan/gdp
# ...

# %% [markdown]
# ##### 5 Specific indicator by ticker
# /country/ticker/{ticker}

# %% [markdown]
# https://api.tradingeconomics.com//country/ticker/usurtot?c=guest:guest

# %%
te.getIndicatorByTicker(ticker='usurtot', output_type='df')
# Out:
#          Country           Category                            Title  \
# 0  United States  Unemployment Rate  United States Unemployment Rate
#
#        LatestValueDate  LatestValue                           Source     Unit  \
# 0  2021-08-31T00:00:00          5.2  U.S. Bureau of Labor Statistics  percent
#
#                                 URL CategoryGroup Adjustment Frequency  \
# 0  /united-states/unemployment-rate        Labour              Monthly
#
#   HistoricalDataSymbol           CreateDate  PreviousValue  \
# 0              USURTOT  2012-02-23T11:41:00            5.4
#
#      PreviousValueDate
# 0  2021-07-31T00:00:00

# %% [markdown]
# ##### 5 Multiple indicators by ticker
# /country/ticker/{ticker}

# %% [markdown]
# https://api.tradingeconomics.com//country/ticker/usurtot,wgdpchin?c=guest:guest

# %%
te.getIndicatorByTicker(ticker=['usurtot','wgdpchin'], output_type='df')
# Out:
#          Country           Category                            Title  \
# 0          China                GDP                        China GDP
# 1  United States  Unemployment Rate  United States Unemployment Rate
#
#        LatestValueDate  LatestValue                           Source  \
# 0  2020-12-31T00:00:00     14722.73                       World Bank
# 1  2021-08-31T00:00:00         5.20  U.S. Bureau of Labor Statistics
#
#           Unit                               URL CategoryGroup   Adjustment  \
# 0  USD Billion                        /china/gdp           GDP  Current USD
# 1      percent  /united-states/unemployment-rate        Labour
#
#   Frequency HistoricalDataSymbol           CreateDate  PreviousValue  \
# 0    Yearly             WGDPCHIN  2013-07-04T13:50:00       14279.94
# 1   Monthly              USURTOT  2012-02-23T11:41:00           5.40
#
#      PreviousValueDate
# 0  2019-12-31T00:00:00
# 1  2021-07-31T00:00:00

# %% [markdown]
# ## Indicators - Historical

# %% [markdown]
# ##### 6 Specific country and indicator
# /historical/country/{countries}/indicator/{indicators}

# %% [markdown]
# https://api.tradingeconomics.com/historical/country/united%20states/indicator/gdp?c=guest:guest

# %%
te.getHistoricalData(country='united states', indicator='gdp', output_type='df')
# Out:
#          Country Category             DateTime     Value Frequency  \
# 0  United States      GDP  2011-12-31T00:00:00  15542.58    Yearly
# 1  United States      GDP  2012-12-31T00:00:00  16197.01    Yearly
# 2  United States      GDP  2013-12-31T00:00:00  16784.85    Yearly
# 3  United States      GDP  2014-12-31T00:00:00  17527.16    Yearly
# 4  United States      GDP  2015-12-31T00:00:00  18238.30    Yearly
# 5  United States      GDP  2016-12-31T00:00:00  18745.08    Yearly
# 6  United States      GDP  2017-12-31T00:00:00  19542.98    Yearly
# 7  United States      GDP  2018-12-31T00:00:00  20611.86    Yearly
# 8  United States      GDP  2019-12-31T00:00:00  21433.22    Yearly
# 9  United States      GDP  2020-12-31T00:00:00  20936.60    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0               WGDPUS  2019-06-25T12:50:00
# 1               WGDPUS  2019-06-25T12:50:00
# 2               WGDPUS  2019-06-25T12:50:00
# 3               WGDPUS  2021-07-05T14:16:00
# ...

# %% [markdown]
# ##### 7  You can specify only a start date for your historical data
# /historical/country/{countries}/indicator/{indicators}/{yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/historical/country/united%20states/indicator/gdp/2013-01-01?c=guest:guest

# %%
te.getHistoricalData(country='united states', indicator='gdp',initDate='2013-01-01', output_type='df')
# Out:
#          Country Category             DateTime     Value Frequency  \
# 0  United States      GDP  2013-12-31T00:00:00  16784.85    Yearly
# 1  United States      GDP  2014-12-31T00:00:00  17527.16    Yearly
# 2  United States      GDP  2015-12-31T00:00:00  18238.30    Yearly
# 3  United States      GDP  2016-12-31T00:00:00  18745.08    Yearly
# 4  United States      GDP  2017-12-31T00:00:00  19542.98    Yearly
# 5  United States      GDP  2018-12-31T00:00:00  20611.86    Yearly
# 6  United States      GDP  2019-12-31T00:00:00  21433.22    Yearly
# 7  United States      GDP  2020-12-31T00:00:00  20936.60    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0               WGDPUS  2019-06-25T12:50:00
# 1               WGDPUS  2021-07-05T14:16:00
# 2               WGDPUS  2021-07-05T14:16:00
# 3               WGDPUS  2021-07-05T14:17:00
# 4               WGDPUS  2021-07-05T14:17:00
# 5               WGDPUS  2021-07-05T14:17:00
# 6               WGDPUS  2021-07-05T14:17:00
# ...

# %% [markdown]
# ##### 8 or you can specify a start date and end date
# /historical/country/{countries}/indicator/{indicators}/{yyyy-mm-dd}/{yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/historical/country/united%20states/indicator/gdp/2015-01-01/2015-12-31?c=guest:guest

# %%
te.getHistoricalData(country='united states', indicator='gdp',initDate='2013-01-01', endDate='2015-12-31', output_type='df')
# Out:
#          Country Category             DateTime     Value Frequency  \
# 0  United States      GDP  2013-12-31T00:00:00  16784.85    Yearly
# 1  United States      GDP  2014-12-31T00:00:00  17527.16    Yearly
# 2  United States      GDP  2015-12-31T00:00:00  18238.30    Yearly
# 3  United States      GDP  2016-12-31T00:00:00  18745.08    Yearly
# 4  United States      GDP  2017-12-31T00:00:00  19542.98    Yearly
# 5  United States      GDP  2018-12-31T00:00:00  20611.86    Yearly
# 6  United States      GDP  2019-12-31T00:00:00  21433.22    Yearly
# 7  United States      GDP  2020-12-31T00:00:00  20936.60    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0               WGDPUS  2019-06-25T12:50:00
# 1               WGDPUS  2021-07-05T14:16:00
# 2               WGDPUS  2021-07-05T14:16:00
# 3               WGDPUS  2021-07-05T14:17:00
# 4               WGDPUS  2021-07-05T14:17:00
# 5               WGDPUS  2021-07-05T14:17:00
# 6               WGDPUS  2021-07-05T14:17:00
# ...

# %% [markdown]
# ##### 9 Multiple indicators for specific country
# /historical/country/{countries}/indicator/{indicators}

# %% [markdown]
# https://api.tradingeconomics.com/historical/country/united%20states/indicator/gdp,population?c=guest:guest

# %%
te.getHistoricalData(country='united states', indicator=['gdp', 'population'], output_type='df')
# Out:
#          Country    Category             DateTime     Value Frequency  \
# 0  United States         GDP  2016-12-31T00:00:00  18745.08    Yearly
# 1  United States  Population  2016-12-31T00:00:00    323.07    Yearly
# 2  United States         GDP  2017-12-31T00:00:00  19542.98    Yearly
# 3  United States  Population  2017-12-31T00:00:00    325.12    Yearly
# 4  United States         GDP  2018-12-31T00:00:00  20611.86    Yearly
# 5  United States  Population  2018-12-31T00:00:00    326.84    Yearly
# 6  United States         GDP  2019-12-31T00:00:00  21433.22    Yearly
# 7  United States  Population  2019-12-31T00:00:00    328.33    Yearly
# 8  United States         GDP  2020-12-31T00:00:00  20936.60    Yearly
# 9  United States  Population  2020-12-31T00:00:00    329.48    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0               WGDPUS  2021-07-05T14:17:00
# 1      USA SP.POP.TOTL  2019-07-15T16:25:00
# 2               WGDPUS  2021-07-05T14:17:00
# ...

# %% [markdown]
# ##### 10 Specific indicator for multiple countries
# /historical/country/{countries}/indicator/{indicators}

# %% [markdown]
# https://api.tradingeconomics.com/historical/country/united%20states,china/indicator/gdp?c=guest:guest

# %%
te.getHistoricalData(country=['united states', 'china'], indicator='gdp', output_type='df')
# Out:
#          Country Category             DateTime     Value Frequency  \
# 0          China      GDP  2016-12-31T00:00:00  11233.28    Yearly
# 1  United States      GDP  2016-12-31T00:00:00  18745.08    Yearly
# 2          China      GDP  2017-12-31T00:00:00  12310.41    Yearly
# 3  United States      GDP  2017-12-31T00:00:00  19542.98    Yearly
# 4          China      GDP  2018-12-31T00:00:00  13894.82    Yearly
# 5  United States      GDP  2018-12-31T00:00:00  20611.86    Yearly
# 6          China      GDP  2019-12-31T00:00:00  14279.94    Yearly
# 7  United States      GDP  2019-12-31T00:00:00  21433.22    Yearly
# 8          China      GDP  2020-12-31T00:00:00  14722.73    Yearly
# 9  United States      GDP  2020-12-31T00:00:00  20936.60    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0             WGDPCHIN  2020-07-02T11:55:00
# 1               WGDPUS  2021-07-05T14:17:00
# 2             WGDPCHIN  2020-07-02T11:55:00
# 3               WGDPUS  2021-07-05T14:17:00
# ...

# %% [markdown]
# ##### 11 Multiple indicators for multiple countries
# /historical/country/{countries}/indicator/{indicators}

# %% [markdown]
# https://api.tradingeconomics.com/historical/country/united%20states,china/indicator/gdp,population?c=guest:guest

# %%
te.getHistoricalData(country=['united states', 'china'], indicator=['gdp','population'], output_type='df')
# Out:
#          Country    Category             DateTime     Value Frequency  \
# 0          China         GDP  2018-12-31T00:00:00  13894.82    Yearly
# 1          China  Population  2018-12-31T00:00:00   1395.38    Yearly
# 2          China         GDP  2019-12-31T00:00:00  14279.94    Yearly
# 3          China  Population  2019-12-31T00:00:00   1400.05    Yearly
# 4  United States         GDP  2019-12-31T00:00:00  21433.22    Yearly
# 5  United States  Population  2019-12-31T00:00:00    328.33    Yearly
# 6          China         GDP  2020-12-31T00:00:00  14722.73    Yearly
# 7          China  Population  2020-12-31T00:00:00   1443.50    Yearly
# 8  United States         GDP  2020-12-31T00:00:00  20936.60    Yearly
# 9  United States  Population  2020-12-31T00:00:00    329.48    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0             WGDPCHIN  2020-07-02T11:55:00
# 1      CHN SP.POP.TOTL  2019-04-09T15:10:00
# 2             WGDPCHIN  2021-07-05T14:28:00
# ...

# %% [markdown]
# ##### 12 Get historical data by ticker
# /historical/ticker/{ticker}/{yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/historical/ticker/USURTOT/2015-03-01?c=guest:guest

# %%
done - test here after deploy  te.getHistoricalByTicker(ticker=None, start_date=None, output_type=None)

# %% [markdown]
# ## Discontinued Series

# %% [markdown]
# ##### 13 - List of discontinued series for all countries.
# /country/all/discontinued

# %% [markdown]
# https://api.tradingeconomics.com/country/all/discontinued?c=guest:guest

# %%
te.getDiscontinuedIndicator( output_type='df')
# Out:
# https://api.tradingeconomics.com/country/all/discontinued?c=guest:guest
#        Country                Category                           Title  \
# 0  Afghanistan           Interest Rate       Afghanistan Interest Rate
# 1      Albania  Changes in Inventories  Albania Changes in Inventories
# 2      Algeria           Export Prices           Algeria Export Prices
# 3      Algeria        Steel Production        Algeria Steel Production
# 4      Algeria          Terms Of Trade          Algeria Terms Of Trade
# 5       Angola          Food Inflation           Luanda Food Inflation
# 6       Angola           Gold Reserves            Angola Gold Reserves
# 7       Angola      Living Wage Family       Angola Living Wage Family
# 8       Angola  Living Wage Individual   Angola Living Wage Individual
# 9       Angola         Money Supply M0          Angola Money Supply M0
#
#        LatestValueDate  LatestValue  \
# 0  2016-12-31T00:00:00        15.00
# 1  2016-12-31T00:00:00    128787.00
# ...

# %% [markdown]
# ##### 14  List of discontinued series by country.
# /country/{country}/discontinued

# %% [markdown]
# https://api.tradingeconomics.com/country/united%20states/discontinued?c=guest:guest

# %%
te.getDiscontinuedIndicator(country='united states', output_type='df')
# Out:
# https://api.tradingeconomics.com/country/united%20states/discontinued?c=guest:guest
#          Country                       Category  \
# 0  United States             Ism New York Index
# 1  United States  Labor Market Conditions Index
# 2  United States             Living Wage Family
# 3  United States         Living Wage Individual
# 4  United States       Small Business Sentiment
# 5  United States             Wages High Skilled
# 6  United States              Wages Low Skilled
#
#                                                Title      LatestValueDate  \
# 0                   United States ISM New York Index  2021-03-31T00:00:00
# 1  United States Change In Labor Market Condition...  2017-06-30T00:00:00
# 2                   United States Living Wage Family  2018-12-31T00:00:00
# 3               United States Living Wage Individual  2018-12-31T00:00:00
# 4                     US Small Business Health Index  2015-02-28T00:00:00
# ...

# %% [markdown]
# ###### 14 List of discontinued series with multiple countries.
# /country/{countries}/discontinued

# %% [markdown]
# https://api.tradingeconomics.com/country/united%20states,china/discontinued?c=guest:guest

# %%
te.getDiscontinuedIndicator(country=['united states','China'], output_type='df')
# Out:
# https://api.tradingeconomics.com/country/united%20states%2CChina/discontinued?c=guest:guest
#          Country                       Category  \
# 0          China                Gdp From Mining
# 1          China            Home Ownership Rate
# 2          China                  Job Vacancies
# 3          China         Leading Economic Index
# 4          China         Mni Business Sentiment
# 5          China         Mni Consumer Sentiment
# 6          China               Personal Savings
# 7  United States             Ism New York Index
# 8  United States  Labor Market Conditions Index
# 9  United States             Living Wage Family
#
#                                                Title      LatestValueDate  \
# 0                              China Gdp From Mining  2018-12-31T00:00:00
# 1                          China Home Ownership Rate  2018-12-31T00:00:00
# 2                                China Job Vacancies  2018-12-31T00:00:00
# ...

# %% [markdown]
# ## Indicators - Forecasts

# %% [markdown]
# ####  15 Specific country
# /forecast/country/{country}

# %% [markdown]
# https://api.tradingeconomics.com/forecast/country/united%20states?c=guest:guest

# %%
te.getForecastData(country='united states', output_type='df')
# Out:
#          Country                    Category  LatestValue  \
# 0  United States       ADP Employment Change       374.00
# 1  United States  API Crude Oil Stock Change        -5.44
# 2  United States     Average Hourly Earnings         0.60
# 3  United States        Average Weekly Hours        34.70
# 4  United States            Balance of Trade    -70051.00
# 5  United States           Bank Lending Rate         3.25
# 6  United States                Bankruptcies     18511.00
# 7  United States         Banks Balance Sheet     22142.40
# 8  United States            Building Permits      1630.00
# 9  United States         Business Confidence        59.90
#
#        LatestValueDate   YearEnd  YearEnd2  YearEnd3        q1  \
# 0  2021-08-31T00:00:00    250.00    150.00    210.00    350.00
# 1  2021-09-10T00:00:00     -2.00      2.00      0.50     -5.00
# 2  2021-08-31T00:00:00      0.20      0.20      0.20      0.40
# 3  2021-08-31T00:00:00     34.60     34.40     34.40     34.70
# ...

# %% [markdown]
# #### 16  Multiple countries
# /forecast/country/{countries}

# %% [markdown]
# https://api.tradingeconomics.com/forecast/country/united%20states,china?c=guest:guest

# %%
te.getForecastData(country=['united states','china'], output_type='df')
# Out:
#          Country                    Category  LatestValue  \
# 0  United States       ADP Employment Change       374.00
# 1  United States  API Crude Oil Stock Change        -5.44
# 2  United States     Average Hourly Earnings         0.60
# 3  United States        Average Weekly Hours        34.70
# 4          China            Balance of Trade       583.31
# 5  United States            Balance of Trade    -70051.00
# 6          China           Bank Lending Rate         2.95
# 7  United States           Bank Lending Rate         3.25
# 8  United States                Bankruptcies     18511.00
# 9          China         Banks Balance Sheet      1220.00
#
#        LatestValueDate   YearEnd  YearEnd2  YearEnd3        q1  \
# 0  2021-08-31T00:00:00    250.00    150.00    210.00    350.00
# 1  2021-09-10T00:00:00     -2.00      2.00      0.50     -5.00
# 2  2021-08-31T00:00:00      0.20      0.20      0.20      0.40
# 3  2021-08-31T00:00:00     34.60     34.40     34.40     34.70
# ...

# %% [markdown]
# #### 17 Specific indicator
# /forecast/indicator/{indicator}

# %% [markdown]
# https://api.tradingeconomics.com/forecast/indicator/gdp?c=guest:guest

# %%
te.getForecastData(indicator='gdp', output_type='df')
# Out:
#                Country Category  LatestValue      LatestValueDate  YearEnd  \
# 0          Afghanistan      GDP        19.81  2020-12-31T00:00:00    20.46
# 1              Albania      GDP        14.80  2020-12-31T00:00:00    17.12
# 2              Algeria      GDP       145.16  2020-12-31T00:00:00   155.00
# 3              Andorra      GDP         3.16  2019-12-31T00:00:00     3.40
# 4               Angola      GDP        62.31  2020-12-31T00:00:00   100.00
# 5  Antigua And Barbuda      GDP         1.42  2020-12-31T00:00:00     1.64
# 6            Argentina      GDP       383.10  2020-12-31T00:00:00   425.00
# 7              Armenia      GDP        12.65  2020-12-31T00:00:00    11.00
# 8                Aruba      GDP         3.20  2018-12-31T00:00:00     2.60
# 9            Australia      GDP      1330.90  2020-12-31T00:00:00  1370.00
#
#    YearEnd2  YearEnd3       q1              q1_date       q2  \
# 0     21.43     21.43    20.46  2021-09-30T00:00:00    20.46
# ...

# %% [markdown]
# #### 17 -Multiple indicators
# /forecast/indicator/{indicators}

# %% [markdown]
# https://api.tradingeconomics.com/forecast/indicator/gdp,population?c=guest:guest

# %%
te.getForecastData(indicator=['gdp','population'], output_type='df')
# Out:
#                Country    Category  LatestValue      LatestValueDate  YearEnd  \
# 0          Afghanistan         GDP        19.81  2020-12-31T00:00:00    20.46
# 1          Afghanistan  Population        33.20  2020-12-31T00:00:00    37.30
# 2              Albania         GDP        14.80  2020-12-31T00:00:00    17.12
# 3              Albania  Population         2.85  2020-12-31T00:00:00     2.84
# 4              Algeria         GDP       145.16  2020-12-31T00:00:00   155.00
# 5              Algeria  Population        44.23  2020-12-31T00:00:00    45.50
# 6              Andorra         GDP         3.16  2019-12-31T00:00:00     3.40
# 7               Angola         GDP        62.31  2020-12-31T00:00:00   100.00
# 8               Angola  Population        33.00  2020-12-30T00:00:00    33.78
# 9  Antigua And Barbuda         GDP         1.42  2020-12-31T00:00:00     1.64
#
#    YearEnd2  YearEnd3      q1              q1_date      q2  \
# ...

# %% [markdown]
# #### 18 Forecast by specific ticker
# /forecast/ticker/{ticker}

# %% [markdown]
# https://api.tradingeconomics.com//forecast/ticker/usurtot?c=guest:guest

# %%
te.getForecastByTicker(ticker='usurtot', output_type='df')
# Out:
# https://api.tradingeconomics.com/forecast/ticker/usurtot?c=guest:guest
#          Country           Category                            Title  \
# 0  United States  Unemployment Rate  United States Unemployment Rate
#
#    LatestValue      LatestValueDate   q1   q2   q3   q4  YearEnd  YearEnd2  \
# 0          5.2  2021-08-31T00:00:00  5.1  5.2  5.2  5.0      5.2       5.0
#
#    YearEnd3              q1_date              q2_date              q3_date  \
# 0       4.3  2021-09-30T00:00:00  2021-12-31T00:00:00  2022-03-31T00:00:00
#
#                q4_date Frequency HistoricalDataSymbol
# 0  2022-06-30T00:00:00   Monthly              USURTOT

# %% [markdown]
# #### 18 Forecasts by multiple tickers
# /forecast/ticker/{tickers}

# %% [markdown]
# https://api.tradingeconomics.com//forecast/ticker/usurtot,wgdpchin?c=guest:guest

# %%
te.getForecastByTicker(ticker=['usurtot','wgdpchin'], output_type='df')
# Out:
# https://api.tradingeconomics.com/forecast/ticker/usurtot%2Cwgdpchin?c=guest:guest
#          Country           Category                            Title  \
# 0  United States  Unemployment Rate  United States Unemployment Rate
# 1          China                GDP                        China GDP
#
#    LatestValue      LatestValueDate       q1       q2       q3       q4  \
# 0         5.20  2021-08-31T00:00:00      5.1      5.2      5.2      5.0
# 1     14722.73  2020-12-31T00:00:00  14600.0  14600.0  15700.0  15700.0
#
#    YearEnd  YearEnd2  YearEnd3              q1_date              q2_date  \
# 0      5.2       5.0       4.3  2021-09-30T00:00:00  2021-12-31T00:00:00
# 1  14600.0   15700.0   16400.0  2021-09-30T00:00:00  2021-12-31T00:00:00
#
#                q3_date              q4_date Frequency HistoricalDataSymbol
# 0  2022-03-31T00:00:00  2022-06-30T00:00:00   Monthly              USURTOT
# 1  2022-03-31T00:00:00  2022-06-30T00:00:00    Yearly             WGDPCHIN

# %% [markdown]
# #### 19 Specific country and indicator
# /forecast/country/{country}/indicator/{indicator}

# %% [markdown]
# https://api.tradingeconomics.com/forecast/country/united%20states/indicator/gdp?c=guest:guest

# %%
te.getIndicatorData(country='united states', indicators='gdp', output_type='df')
# Out:
#          Country Category              Title  LatestValue  \
# 0  United States      GDP  United States GDP      20936.6
#
#        LatestValueDate      Source         Unit                 URL  \
# 0  2020-12-31T00:00:00  World Bank  USD Billion  /united-states/gdp
#
#   CategoryGroup   Adjustment Frequency HistoricalDataSymbol  \
# 0           GDP  Current USD    Yearly               WGDPUS
#
#             CreateDate  PreviousValue    PreviousValueDate
# 0  2014-07-03T16:14:00       21433.22  2019-12-31T00:00:00

# %% [markdown]
# #### 19 Multiple countries and indicators
# /forecast/country/{countries}/indicator/{indicators}

# %% [markdown]
# https://api.tradingeconomics.com/forecast/country/united%20states,china/indicator/gdp,population?c=guest:guest

# %%
te.getForecastData(country = ['United States', 'china'], indicator = ['gdp', 'population'], output_type='df')
# Out:
#          Country    Category  LatestValue      LatestValueDate   YearEnd  \
# 0          China         GDP     14722.73  2020-12-31T00:00:00  14600.00
# 1  United States         GDP     20936.60  2020-12-31T00:00:00  21500.00
# 2          China  Population      1443.50  2020-12-31T00:00:00   1465.00
# 3  United States  Population       329.48  2020-12-31T00:00:00    333.23
#
#    YearEnd2  YearEnd3        q1              q1_date        q2  \
# 0  15700.00  16400.00  14600.00  2021-09-30T00:00:00  14600.00
# 1  22790.00  22790.00  21500.00  2021-09-30T00:00:00  21500.00
# 2   1495.00   1540.00   1465.00  2021-09-30T00:00:00   1465.00
# 3    335.25    335.25    331.21  2021-09-30T00:00:00    333.23
#
#                q2_date        q3              q3_date        q4  \
# 0  2021-12-31T00:00:00  15700.00  2022-03-31T00:00:00  15700.00
# 1  2021-12-31T00:00:00  21500.00  2022-03-31T00:00:00  21500.00
# 2  2021-12-31T00:00:00   1495.00  2022-03-31T00:00:00   1495.00
# ...

# %% [markdown]
# ## Indicators - Credit Rating

# %% [markdown]
# ##### 20 Latest Credit Ratings.
# /ratings

# %% [markdown]
# https://api.tradingeconomics.com/ratings?c=guest:guest

# %%
te.getRatings(output_type='df')
# Out:
#         Country  TE      TE_Outlook     SP SP_Outlook Moodys Moodys_Outlook  \
# 0       Albania  35          Stable     B+     Stable     B1         Stable
# 1       Andorra  62        Positive    BBB     Stable
# 2        Angola  20          Stable   CCC+     Stable     B3         Stable
# 3     Argentina  15          Stable   CCC+     Stable     Ca         Stable
# 4       Armenia  16        Negative                      Ba3         Stable
# ..          ...  ..             ...    ...        ...    ...            ...
# 150     Uruguay  55        Negative  \tBBB     Stable   Baa2         Stable
# 151  Uzbekistan  38          Stable    BB-     Stable     B1       Positive
# 152   Venezuela  11  Negative Watch     SD        N/A     WR            N/A
# 153     Vietnam  43          Stable     BB   Positive    Ba3       Positive
# 154      Zambia  30        Negative     SD        N/A     Ca         Stable
#
#     Fitch Fitch_Outlook  Outlook       DBRS DBRS_Outlook
# ...

# %% [markdown]
# ##### 21 Credit Rating of the specific country
# /ratings/{country}

# %% [markdown]
# https://api.tradingeconomics.com/ratings/united%20states?c=guest:guest

# %%
te.getRatings(country='united states', output_type='df')
# Out:
#          Country  TE TE_Outlook   SP SP_Outlook Moodys Moodys_Outlook Fitch  \
# 0  United States  98     Stable  AA+     Stable    Aaa         Stable   AAA
#
#   Fitch_Outlook  Outlook DBRS DBRS_Outlook
# 0      Negative      NaN  AAA       Stable

# %% [markdown]
# ##### 21 Credit Rating for multiple countries
# /ratings/{countries}

# %% [markdown]
# https://api.tradingeconomics.com/ratings/united%20states,portugal?c=guest:guest

# %%
te.getRatings(country=['united states','china'], output_type='df')
# Out:
#          Country  TE TE_Outlook   SP SP_Outlook Moodys Moodys_Outlook Fitch  \
# 0          China  80     Stable   A+     Stable     A1         Stable    A+
# 1  United States  98     Stable  AA+     Stable    Aaa         Stable   AAA
#
#   Fitch_Outlook  Outlook      DBRS DBRS_Outlook
# 0        Stable      NaN  A (high)       Stable
# 1      Negative      NaN       AAA       Stable

# %% [markdown]
# ##### 22 Historical credit rating for one country
# /ratings/historical/{country}

# %% [markdown]
# https://api.tradingeconomics.com/ratings/historical/united%20states?c=guest:guest

# %%
te.getHistoricalRatings(country='united states', output_type='df')
# Out:
#           Country        Date   Agency Rating         Outlook
# 0   United States   7/31/2020    Fitch    AAA        Negative
# 1   United States   4/22/2014     DBRS    AAA          Stable
# 2   United States   3/21/2014    Fitch    AAA          Stable
# 3   United States  10/15/2013    Fitch    AAA  Negative Watch
# 4   United States   10/9/2013     DBRS    AAA    Under Review
# 5   United States   7/18/2013  Moody's    Aaa          Stable
# 6   United States   6/10/2013      S&P    AA+          Stable
# 7   United States  11/28/2011    Fitch    AAA        Negative
# 8   United States    9/8/2011     DBRS    AAA          Stable
# 9   United States    8/5/2011      S&P    AA+        Negative
# 10  United States    8/2/2011  Moody's    Aaa        Negative
# 11  United States   7/14/2011      S&P    AAA  Negative Watch
# 12  United States   7/13/2011  Moody's    Aaa  Negative Watch
# 13  United States   4/18/2011      S&P    AAA        Negative
# ...

# %% [markdown]
# ##### 22 Historical credit rating for multiple countries
# /ratings/historical/{countries}

# %% [markdown]
# https://api.tradingeconomics.com/ratings/historical/united%20states,portugal?c=guest:guest

# %%
te.getHistoricalRatings(country=['united states','portugal'], output_type='df')
# Out:
#           Country        Date   Agency      Rating   Outlook
# 0   United States   7/31/2020    Fitch         AAA  Negative
# 1        Portugal   4/24/2020      S&P         BBB    Stable
# 2        Portugal   4/17/2020    Fitch         BBB    Stable
# 3        Portugal   10/4/2019     DBRS  BBB (high)    Stable
# 4        Portugal   9/13/2019      S&P         BBB  Positive
# ..            ...         ...      ...         ...       ...
# 91       Portugal  10/26/1989      S&P           A    Stable
# 92       Portugal   6/26/1989      S&P           A  Positive
# 93       Portugal   10/1/1988      S&P           A       N/A
# 94       Portugal  11/18/1986  Moody's          A1    Stable
# 95  United States    2/5/1949  Moody's         Aaa    Stable
#
# [96 rows x 5 columns]

# %% [markdown]
# ##### 23 Historical credit rating by start and end date
# /ratings/historical/{country}/{yyyy-mm-dd}/{yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/ratings/historical/united%20states/2011-01-01/2012-01-01?c=guest:guest

# %%
te.getHistoricalRatings(country = 'United States', initDate ='2011-01-01', endDate = '2012-01-01', output_type='df')
# Out:
#          Country        Date   Agency Rating         Outlook
# 0  United States  11/28/2011    Fitch    AAA        Negative
# 1  United States    9/8/2011     DBRS    AAA          Stable
# 2  United States    8/5/2011      S&P    AA+        Negative
# 3  United States    8/2/2011  Moody's    Aaa        Negative
# 4  United States   7/14/2011      S&P    AAA  Negative Watch
# 5  United States   7/13/2011  Moody's    Aaa  Negative Watch
# 6  United States   4/18/2011      S&P    AAA        Negative

# %% [markdown]
# ##### 24 You can specify only a start date
# /ratings/historical/{country}/{yyyy-mm-dd}

# %% [markdown]
# https://api.tradingeconomics.com/ratings/historical/united%20states/2011-01-01/2012-01-01?c=guest:guest

# %%
te.getHistoricalRatings(country = 'United States', initDate ='2011-01-01', output_type='df')
# Out:
#           Country        Date   Agency Rating         Outlook
# 0   United States   7/31/2020    Fitch    AAA        Negative
# 1   United States   4/22/2014     DBRS    AAA          Stable
# 2   United States   3/21/2014    Fitch    AAA          Stable
# 3   United States  10/15/2013    Fitch    AAA  Negative Watch
# 4   United States   10/9/2013     DBRS    AAA    Under Review
# 5   United States   7/18/2013  Moody's    Aaa          Stable
# 6   United States   6/10/2013      S&P    AA+          Stable
# 7   United States  11/28/2011    Fitch    AAA        Negative
# 8   United States    9/8/2011     DBRS    AAA          Stable
# 9   United States    8/5/2011      S&P    AA+        Negative
# 10  United States    8/2/2011  Moody's    Aaa        Negative
# 11  United States   7/14/2011      S&P    AAA  Negative Watch
# 12  United States   7/13/2011  Moody's    Aaa  Negative Watch
# 13  United States   4/18/2011      S&P    AAA        Negative

# %% [markdown]
# ## Latest updates

# %% [markdown]
# ##### 25 Latest updates
# /updates

# %% [markdown]
# https://api.tradingeconomics.com/updates?client=guest:guest

# %%
te.getLatestUpdates(output_type = 'df')
# Out:
#          Country             Category HistoricalDataSymbol  \
# 0  United States  Consumer Confidence             CONCCONF
# 1        Nigeria        Interest Rate       NIGERIAINTRATE
# 2     Azerbaijan        Interest Rate      AZEIJANINTTRATE
# 3        Bahrain      Money Supply M1      BAHRAINMONSUPM1
# 4        Bahrain      Money Supply M2      BAHRAINMONSUPM2
# 5         Serbia        Capital Flows         SERBIACAPFLO
# 6         Serbia      Current Account      SERRBIACURCOUNT
# 7        Lebanon       Inflation Rate      LEBANONINFNRATE
# 8       Zimbabwe       Inflation Rate      ZIMABWEINFNRATE
# 9       Zimbabwe   Inflation Rate Mom    ZIMBABWEINFRATMOM
#
#             LastUpdate
# 0  2021-09-17T14:17:00
# 1  2021-09-17T14:16:00
# 2  2021-09-17T13:56:00
# 3  2021-09-17T13:32:00
# 4  2021-09-17T13:32:00
# 5  2021-09-17T13:21:00
# 6  2021-09-17T13:20:00
# 7  2021-09-17T13:13:00
# 8  2021-09-17T13:09:00
# 9  2021-09-17T13:09:00

# %% [markdown]
# ##### 26 Updates since a start date
# /updates/{date}

# %% [markdown]
# https://api.tradingeconomics.com/updates/2018-01-01?client=guest:guest

# %%
te.getLatestUpdates(initDate = '2018-08-15', output_type = 'df')
# Out:
#      Country                  Category HistoricalDataSymbol  \
# 0  Australia                  Calendar
# 1      Japan                  Calendar
# 2   Zimbabwe            Internet Speed              ZWEKBPS
# 3   Zimbabwe  Personal Income Tax Rate            ZWEIRSTAX
# 4   Zimbabwe              IP Addresses               ZWEIPS
# 5   Zimbabwe    Ease of Doing Business       ZWEICBUSEASEXQ
# 6   Zimbabwe        Corporate Tax Rate           ZWECORPTAX
# 7   Zimbabwe          Tourist Arrivals       ZIMBABWETOUARR
# 8   Zimbabwe           Terrorism Index       ZIMBABWETERIND
# 9   Zimbabwe            Sales Tax Rate    ZIMBABWESALTAXRAT
#
#             LastUpdate
# 0  2020-01-10T16:08:00
# 1  2020-11-17T09:23:00
# 2  2021-07-13T23:17:00
# 3  2021-07-13T23:17:00
# 4  2021-07-13T23:17:00
# 5  2021-07-13T23:17:00
# 6  2021-07-13T23:17:00
# 7  2021-07-13T23:17:00
# 8  2021-07-13T23:17:00
# 9  2021-07-13T23:17:00

# %% [markdown]
# ##### 27 Get the Latest Updates by country.
# /updates/country/{country}

# %% [markdown]
# https://api.tradingeconomics.com/updates/country/portugal?client=guest:guest

# %%
te.getLatestUpdates(country='portugal', output_type='df')
# Out:
#     Country                        Category  HistoricalDataSymbol  \
# 0  Portugal  Labor Force Participation Rate  PORTUGALLABFORPARRAT
# 1  Portugal                   Credit Rating
# 2  Portugal   Coronavirus Vaccination Total             PTCOVIDVT
# 3  Portugal           Coronavirus Recovered             PTCOVIDRT
# 4  Portugal    Coronavirus Vaccination Rate             PTCOVIDVR
# 5  Portugal                 Current Account              PTCUEURO
# 6  Portugal                   Capital Flows        PORTUGALCAPFLO
# 7  Portugal       Foreign Direct Investment     PORTUGALFORDIRINV
# 8  Portugal                Tourist Arrivals        PORTUGALTOUARR
# 9  Portugal      Central Bank Balance Sheet  PORTUGALCENBANBALSHE
#
#             LastUpdate
# 0  2021-09-21T11:18:00
# 1  2021-09-21T10:15:00
# 2  2021-09-21T02:25:00
# 3  2021-09-21T02:24:00
# 4  2021-09-21T02:24:00
# 5  2021-09-20T11:35:00
# 6  2021-09-20T10:25:00
# 7  2021-09-20T10:25:00
# 8  2021-09-18T10:12:00
# ...

# %% [markdown]
# ##### 28 Get the Latest Updates by country since a start date
# /updates/country/{country}/{date}

# %% [markdown]
# https://api.tradingeconomics.com/updates/country/portugal/2018-01-01?client=guest:guest

# %%
te.getLatestUpdates(country='portugal', init_date='2018-01-01', output_type='df')
# Out:
#     Country                            Category HistoricalDataSymbol  \
# 0  Portugal                                 GDP             WGDPPORT
# 1  Portugal                   Government Budget              WCSDPRT
# 2  Portugal                              Nurses               PTNURS
# 3  Portugal                            ICU Beds               PTICUB
# 4  Portugal                           Hospitals               PTHOSP
# 5  Portugal                       Hospital Beds               PTBEDS
# 6  Portugal  Social Security Rate For Employees              PRTSSRE
# 7  Portugal  Social Security Rate For Companies              PRTSSRC
# 8  Portugal                Social Security Rate               PRTSSR
# 9  Portugal                      Sales Tax Rate          PRTSALESTAX
#
#             LastUpdate
# 0  2021-07-13T23:17:00
# 1  2021-07-13T23:17:00
# 2  2021-07-13T23:17:00
# 3  2021-07-13T23:17:00
# 4  2021-07-13T23:17:00
# 5  2021-07-13T23:17:00
# 6  2021-07-13T23:17:00
# ...
