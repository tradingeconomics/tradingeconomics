# %%
# %run TE.ipynb

# %%
myData = TEGetData(['United States', 'United Kingdom', 'Japan'],
                   ['GDP Growth Rate', 'Inflation Rate', 'Business Confidence','Unemployment Rate', 'Stock Market','Government Bond 10Y', 'Currency','Current Account'])
#print myData

# %%
#TEIndicatorCharts(myData,  [('Japan', 'United States'), ('Japan', 'United Kingdom')],
#                  ['Inflation Rate'])

# %%
#TECountryCharts(myData, ['Japan'], [('GDP Growth Rate','Business Confidence'),
#                  ('Inflation Rate','Unemployment Rate'),
#                  ('Stock Market','Government Bond 10Y'),
#                  ('Currency','Current Account')])

# %%
corFrame = TECorr(myData, ['United Kingdom'])
corFrame
# Out:
# /opt/conda/envs/py2/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                      Business Confidence  Currency  Current Account  \
# Business Confidence             1.000000  0.609650         0.362024
# Currency                        0.609650  1.000000         0.502559
# Current Account                 0.362024  0.502559         1.000000
# GDP Growth Rate                 0.175761  0.570241         0.109441
# Government Bond 10Y             0.679322  0.877066         0.434928
# Inflation Rate                  0.206676 -0.257519         0.259900
# Stock Market                    0.090275 -0.360950        -0.068825
# Unemployment Rate               0.658026  0.936676         0.097060
#
# ...

# %%
TECorrPlot(corFrame)

# %%
corFrame = TECorr(myData, ['GDP Growth Rate'])
corFrame
# Out:
# /opt/conda/envs/py2/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Japan  United Kingdom  United States
# Japan           1.000000       -0.612075      -0.504566
# United Kingdom -0.612075        1.000000       0.575507
# United States  -0.504566        0.575507       1.000000

# %%
TECorrPlot(corFrame)
